# %%
from GraphTsetlinMachine.graphs import Graphs
import numpy as np
import random
from time import time

from GraphTsetlinMachine.tm import MultiClassGraphTsetlinMachine

# %%
def default_args(**kwargs):
    args = {
        "epochs": 10,
        "number_of_clauses": 10,
        "T": 100,
        "s": 1.0,
        "depth": 2,
        "hypervector_size": 32,
        "hypervector_bits": 2,
        "message_size": 256,
        "message_bits": 2,
        "double_hashing": False,
        "noise": 0.01,
        "number_of_examples": 10000,
        "max_included_literals": 4,
    }

    # Override the defaults with any provided keyword arguments
    for key, value in kwargs.items():
        if key in args:
            args[key] = value

    # Convert to an object-like structure
    class Args:
        pass

    args_obj = Args()
    for key, value in args.items():
        setattr(args_obj, key, value)

    return args_obj

args = default_args()

# %%
map_size = 7 # 7 x 7
data_size = 10000
directions = [
    (-1, 0), (1, 0),  # Left and Right
    (0, -1), (0, 1),  # Up and Down
    (-1, 1), (1, -1)  # Upper-left and Lower-right for staggered rows
]

# %%
smbols = ['A, 'O', 'B']
graphs_train = Graphs(
    args.number_of_examples,
    symbols = smbols,
    hypervector_size = args.hypervector_size,
    hypervector_bits = args.hypervector_bits
)

# %%
for graph_id in range(data_size):
    graphs_train.set_number_of_graph_nodes(graph_id, 49)

# %%
graphs_train.prepare_node_configuration()

# %%
n_training = 0

node_counter = 1  # Start node counter from 1
for graph_id in range(n_training):
    for x in range(map_size):
        for y in range(map_size):
            node_id = y * map_size + x
            
            
            for dx, dy in directions:
            neighbor_x = x + dx
            neighbor_y = y + dy
    
            # Check if neighbor exists within bounds
            if 0 <= neighbor_x < map_size and 0 <= neighbor_y < map_size:
                number_of_outgoing_edges += 1

            # Use the node_counter to create a unique label for each node
            node_label = f'Node {node_counter}'
            graphs_train.add_graph_node(graph_id, node_label, number_of_outgoing_edges)

            node_counter += 1  # Increment node counter

# %%
graphs_train.prepare_edge_configuration()

# %%
for graph_id in range(10000):
    edge_type = "Plain"
    graphs_train.add_graph_node_edge(graph_id, 'Node 1', 'Node 2', edge_type)
    graphs_train.add_graph_node_edge(graph_id, 'Node 2', 'Node 1', edge_type)

# %%
Y_train = np.empty(10000, dtype=np.uint32)
for graph_id in range(10000):
    x1 = random.choice(['A', 'B'])
    x2 = random.choice(['A', 'B'])

    graphs_train.add_graph_node_property(graph_id, 'Node 1', x1)
    graphs_train.add_graph_node_property(graph_id, 'Node 2', x2)

    if x1 == x2:
        Y_train[graph_id] = 0
    else:
        Y_train[graph_id] = 1

graphs_train.encode()
# Out:
# Node 'Node 1' of graph 0 misses edges.
# Node 'Node 2' of graph 0 misses edges.
# Node 'Node 1' of graph 1 misses edges.
# Node 'Node 2' of graph 1 misses edges.
# Node 'Node 1' of graph 2 misses edges.
# Node 'Node 2' of graph 2 misses edges.
# Node 'Node 1' of graph 3 misses edges.
# Node 'Node 2' of graph 3 misses edges.
# Node 'Node 1' of graph 4 misses edges.
# Node 'Node 2' of graph 4 misses edges.
# Node 'Node 1' of graph 5 misses edges.
# Node 'Node 2' of graph 5 misses edges.
# Node 'Node 1' of graph 6 misses edges.
# Node 'Node 2' of graph 6 misses edges.
# Node 'Node 1' of graph 7 misses edges.
# Node 'Node 2' of graph 7 misses edges.
# Node 'Node 1' of graph 8 misses edges.
# Node 'Node 2' of graph 8 misses edges.
# Node 'Node 1' of graph 9 misses edges.
# Node 'Node 2' of graph 9 misses edges.
# Node 'Node 1' of graph 10 misses edges.
# Node 'Node 2' of graph 10 misses edges.
# Node 'Node 1' of graph 11 misses edges.
# Node 'Node 2' of graph 11 misses edges.
# Node 'Node 1' of graph 12 misses edges.
# Node 'Node 2' of graph 12 misses edges.
# Node 'Node 1' of graph 13 misses edges.
# Node 'Node 2' of graph 13 misses edges.
# Node 'Node 1' of graph 14 misses edges.
# Node 'Node 2' of graph 14 misses edges.
# Node 'Node 1' of graph 15 misses edges.
# Node 'Node 2' of graph 15 misses edges.
# Node 'Node 1' of graph 16 misses edges.
# Node 'Node 2' of graph 16 misses edges.
# Node 'Node 1' of graph 17 misses edges.
# Node 'Node 2' of graph 17 misses edges.
# Node 'Node 1' of graph 18 misses edges.
# Node 'Node 2' of graph 18 misses edges.
# Node 'Node 1' of graph 19 misses edges.
# Node 'Node 2' of graph 19 misses edges.
# Node 'Node 1' of graph 20 misses edges.
# Node 'Node 2' of graph 20 misses edges.
# Node 'Node 1' of graph 21 misses edges.
# Node 'Node 2' of graph 21 misses edges.
# Node 'Node 1' of graph 22 misses edges.
# Node 'Node 2' of graph 22 misses edges.
# Node 'Node 1' of graph 23 misses edges.
# Node 'Node 2' of graph 23 misses edges.
# Node 'Node 1' of graph 24 misses edges.
# Node 'Node 2' of graph 24 misses edges.
# Node 'Node 1' of graph 25 misses edges.
# Node 'Node 2' of graph 25 misses edges.
# Node 'Node 1' of graph 26 misses edges.
# Node 'Node 2' of graph 26 misses edges.
# Node 'Node 1' of graph 27 misses edges.
# Node 'Node 2' of graph 27 misses edges.
# Node 'Node 1' of graph 28 misses edges.
# Node 'Node 2' of graph 28 misses edges.
# Node 'Node 1' of graph 29 misses edges.
# Node 'Node 2' of graph 29 misses edges.
# Node 'Node 1' of graph 30 misses edges.
# Node 'Node 2' of graph 30 misses edges.
# Node 'Node 1' of graph 31 misses edges.
# Node 'Node 2' of graph 31 misses edges.
# Node 'Node 1' of graph 32 misses edges.
# Node 'Node 2' of graph 32 misses edges.
# Node 'Node 1' of graph 33 misses edges.
# Node 'Node 2' of graph 33 misses edges.
# Node 'Node 1' of graph 34 misses edges.
# Node 'Node 2' of graph 34 misses edges.
# Node 'Node 1' of graph 35 misses edges.
# Node 'Node 2' of graph 35 misses edges.
# Node 'Node 1' of graph 36 misses edges.
# Node 'Node 2' of graph 36 misses edges.
# Node 'Node 1' of graph 37 misses edges.
# Node 'Node 2' of graph 37 misses edges.
# Node 'Node 1' of graph 38 misses edges.
# Node 'Node 2' of graph 38 misses edges.
# Node 'Node 1' of graph 39 misses edges.
# Node 'Node 2' of graph 39 misses edges.
# Node 'Node 1' of graph 40 misses edges.
# Node 'Node 2' of graph 40 misses edges.
# Node 'Node 1' of graph 41 misses edges.
# Node 'Node 2' of graph 41 misses edges.
# Node 'Node 1' of graph 42 misses edges.
# Node 'Node 2' of graph 42 misses edges.
# Node 'Node 1' of graph 43 misses edges.
# Node 'Node 2' of graph 43 misses edges.
# Node 'Node 1' of graph 44 misses edges.
# Node 'Node 2' of graph 44 misses edges.
# Node 'Node 1' of graph 45 misses edges.
# Node 'Node 2' of graph 45 misses edges.
# Node 'Node 1' of graph 46 misses edges.
# Node 'Node 2' of graph 46 misses edges.
# Node 'Node 1' of graph 47 misses edges.
# Node 'Node 2' of graph 47 misses edges.
# Node 'Node 1' of graph 48 misses edges.
# Node 'Node 2' of graph 48 misses edges.
# Node 'Node 1' of graph 49 misses edges.
# Node 'Node 2' of graph 49 misses edges.
# Node 'Node 1' of graph 50 misses edges.
# Node 'Node 2' of graph 50 misses edges.
# Node 'Node 1' of graph 51 misses edges.
# Node 'Node 2' of graph 51 misses edges.
# Node 'Node 1' of graph 52 misses edges.
# Node 'Node 2' of graph 52 misses edges.
# Node 'Node 1' of graph 53 misses edges.
# Node 'Node 2' of graph 53 misses edges.
# Node 'Node 1' of graph 54 misses edges.
# Node 'Node 2' of graph 54 misses edges.
# Node 'Node 1' of graph 55 misses edges.
# Node 'Node 2' of graph 55 misses edges.
# Node 'Node 1' of graph 56 misses edges.
# Node 'Node 2' of graph 56 misses edges.
# Node 'Node 1' of graph 57 misses edges.
# Node 'Node 2' of graph 57 misses edges.
# Node 'Node 1' of graph 58 misses edges.
# Node 'Node 2' of graph 58 misses edges.
# Node 'Node 1' of graph 59 misses edges.
# Node 'Node 2' of graph 59 misses edges.
# Node 'Node 1' of graph 60 misses edges.
# Node 'Node 2' of graph 60 misses edges.
# Node 'Node 1' of graph 61 misses edges.
# Node 'Node 2' of graph 61 misses edges.
# Node 'Node 1' of graph 62 misses edges.
# Node 'Node 2' of graph 62 misses edges.
# Node 'Node 1' of graph 63 misses edges.
# Node 'Node 2' of graph 63 misses edges.
# Node 'Node 1' of graph 64 misses edges.
# Node 'Node 2' of graph 64 misses edges.
# Node 'Node 1' of graph 65 misses edges.
# Node 'Node 2' of graph 65 misses edges.
# Node 'Node 1' of graph 66 misses edges.
# Node 'Node 2' of graph 66 misses edges.
# Node 'Node 1' of graph 67 misses edges.
# Node 'Node 2' of graph 67 misses edges.
# Node 'Node 1' of graph 68 misses edges.
# Node 'Node 2' of graph 68 misses edges.
# Node 'Node 1' of graph 69 misses edges.
# Node 'Node 2' of graph 69 misses edges.
# Node 'Node 1' of graph 70 misses edges.
# Node 'Node 2' of graph 70 misses edges.
# Node 'Node 1' of graph 71 misses edges.
# Node 'Node 2' of graph 71 misses edges.
# Node 'Node 1' of graph 72 misses edges.
# Node 'Node 2' of graph 72 misses edges.
# Node 'Node 1' of graph 73 misses edges.
# Node 'Node 2' of graph 73 misses edges.
# Node 'Node 1' of graph 74 misses edges.
# Node 'Node 2' of graph 74 misses edges.
# Node 'Node 1' of graph 75 misses edges.
# Node 'Node 2' of graph 75 misses edges.
# Node 'Node 1' of graph 76 misses edges.
# Node 'Node 2' of graph 76 misses edges.
# Node 'Node 1' of graph 77 misses edges.
# Node 'Node 2' of graph 77 misses edges.
# Node 'Node 1' of graph 78 misses edges.
# Node 'Node 2' of graph 78 misses edges.
# Node 'Node 1' of graph 79 misses edges.
# Node 'Node 2' of graph 79 misses edges.
# Node 'Node 1' of graph 80 misses edges.
# Node 'Node 2' of graph 80 misses edges.
# Node 'Node 1' of graph 81 misses edges.
# Node 'Node 2' of graph 81 misses edges.
# Node 'Node 1' of graph 82 misses edges.
# Node 'Node 2' of graph 82 misses edges.
# Node 'Node 1' of graph 83 misses edges.
# Node 'Node 2' of graph 83 misses edges.
# Node 'Node 1' of graph 84 misses edges.
# Node 'Node 2' of graph 84 misses edges.
# Node 'Node 1' of graph 85 misses edges.
# Node 'Node 2' of graph 85 misses edges.
# Node 'Node 1' of graph 86 misses edges.
# Node 'Node 2' of graph 86 misses edges.
# Node 'Node 1' of graph 87 misses edges.
# Node 'Node 2' of graph 87 misses edges.
# Node 'Node 1' of graph 88 misses edges.
# Node 'Node 2' of graph 88 misses edges.
# Node 'Node 1' of graph 89 misses edges.
# Node 'Node 2' of graph 89 misses edges.
# Node 'Node 1' of graph 90 misses edges.
# Node 'Node 2' of graph 90 misses edges.
# Node 'Node 1' of graph 91 misses edges.
# Node 'Node 2' of graph 91 misses edges.
# Node 'Node 1' of graph 92 misses edges.
# Node 'Node 2' of graph 92 misses edges.
# Node 'Node 1' of graph 93 misses edges.
# Node 'Node 2' of graph 93 misses edges.
# Node 'Node 1' of graph 94 misses edges.
# Node 'Node 2' of graph 94 misses edges.
# Node 'Node 1' of graph 95 misses edges.
# Node 'Node 2' of graph 95 misses edges.
# Node 'Node 1' of graph 96 misses edges.
# Node 'Node 2' of graph 96 misses edges.
# Node 'Node 1' of graph 97 misses edges.
# Node 'Node 2' of graph 97 misses edges.
# Node 'Node 1' of graph 98 misses edges.
# Node 'Node 2' of graph 98 misses edges.
# Node 'Node 1' of graph 99 misses edges.
# Node 'Node 2' of graph 99 misses edges.
# Node 'Node 1' of graph 100 misses edges.
# Node 'Node 2' of graph 100 misses edges.
# Node 'Node 1' of graph 101 misses edges.
# Node 'Node 2' of graph 101 misses edges.
# Node 'Node 1' of graph 102 misses edges.
# Node 'Node 2' of graph 102 misses edges.
# Node 'Node 1' of graph 103 misses edges.
# Node 'Node 2' of graph 103 misses edges.
# Node 'Node 1' of graph 104 misses edges.
# Node 'Node 2' of graph 104 misses edges.
# Node 'Node 1' of graph 105 misses edges.
# Node 'Node 2' of graph 105 misses edges.
# Node 'Node 1' of graph 106 misses edges.
# Node 'Node 2' of graph 106 misses edges.
# Node 'Node 1' of graph 107 misses edges.
# Node 'Node 2' of graph 107 misses edges.
# Node 'Node 1' of graph 108 misses edges.
# Node 'Node 2' of graph 108 misses edges.
# Node 'Node 1' of graph 109 misses edges.
# Node 'Node 2' of graph 109 misses edges.
# Node 'Node 1' of graph 110 misses edges.
# Node 'Node 2' of graph 110 misses edges.
# Node 'Node 1' of graph 111 misses edges.
# Node 'Node 2' of graph 111 misses edges.
# Node 'Node 1' of graph 112 misses edges.
# Node 'Node 2' of graph 112 misses edges.
# Node 'Node 1' of graph 113 misses edges.
# Node 'Node 2' of graph 113 misses edges.
# Node 'Node 1' of graph 114 misses edges.
# Node 'Node 2' of graph 114 misses edges.
# Node 'Node 1' of graph 115 misses edges.
# Node 'Node 2' of graph 115 misses edges.
# Node 'Node 1' of graph 116 misses edges.
# Node 'Node 2' of graph 116 misses edges.
# Node 'Node 1' of graph 117 misses edges.
# Node 'Node 2' of graph 117 misses edges.
# Node 'Node 1' of graph 118 misses edges.
# Node 'Node 2' of graph 118 misses edges.
# Node 'Node 1' of graph 119 misses edges.
# Node 'Node 2' of graph 119 misses edges.
# Node 'Node 1' of graph 120 misses edges.
# Node 'Node 2' of graph 120 misses edges.
# Node 'Node 1' of graph 121 misses edges.
# Node 'Node 2' of graph 121 misses edges.
# Node 'Node 1' of graph 122 misses edges.
# Node 'Node 2' of graph 122 misses edges.
# Node 'Node 1' of graph 123 misses edges.
# Node 'Node 2' of graph 123 misses edges.
# Node 'Node 1' of graph 124 misses edges.
# Node 'Node 2' of graph 124 misses edges.
# Node 'Node 1' of graph 125 misses edges.
# Node 'Node 2' of graph 125 misses edges.
# Node 'Node 1' of graph 126 misses edges.
# Node 'Node 2' of graph 126 misses edges.
# Node 'Node 1' of graph 127 misses edges.
# Node 'Node 2' of graph 127 misses edges.
# Node 'Node 1' of graph 128 misses edges.
# Node 'Node 2' of graph 128 misses edges.
# Node 'Node 1' of graph 129 misses edges.
# Node 'Node 2' of graph 129 misses edges.
# Node 'Node 1' of graph 130 misses edges.
# Node 'Node 2' of graph 130 misses edges.
# Node 'Node 1' of graph 131 misses edges.
# Node 'Node 2' of graph 131 misses edges.
# Node 'Node 1' of graph 132 misses edges.
# Node 'Node 2' of graph 132 misses edges.
# Node 'Node 1' of graph 133 misses edges.
# Node 'Node 2' of graph 133 misses edges.
# Node 'Node 1' of graph 134 misses edges.
# Node 'Node 2' of graph 134 misses edges.
# Node 'Node 1' of graph 135 misses edges.
# Node 'Node 2' of graph 135 misses edges.
# Node 'Node 1' of graph 136 misses edges.
# Node 'Node 2' of graph 136 misses edges.
# Node 'Node 1' of graph 137 misses edges.
# Node 'Node 2' of graph 137 misses edges.
# Node 'Node 1' of graph 138 misses edges.
# Node 'Node 2' of graph 138 misses edges.
# Node 'Node 1' of graph 139 misses edges.
# Node 'Node 2' of graph 139 misses edges.
# Node 'Node 1' of graph 140 misses edges.
# Node 'Node 2' of graph 140 misses edges.
# Node 'Node 1' of graph 141 misses edges.
# Node 'Node 2' of graph 141 misses edges.
# Node 'Node 1' of graph 142 misses edges.
# Node 'Node 2' of graph 142 misses edges.
# Node 'Node 1' of graph 143 misses edges.
# Node 'Node 2' of graph 143 misses edges.
# Node 'Node 1' of graph 144 misses edges.
# Node 'Node 2' of graph 144 misses edges.
# Node 'Node 1' of graph 145 misses edges.
# Node 'Node 2' of graph 145 misses edges.
# Node 'Node 1' of graph 146 misses edges.
# Node 'Node 2' of graph 146 misses edges.
# Node 'Node 1' of graph 147 misses edges.
# Node 'Node 2' of graph 147 misses edges.
# Node 'Node 1' of graph 148 misses edges.
# Node 'Node 2' of graph 148 misses edges.
# Node 'Node 1' of graph 149 misses edges.
# Node 'Node 2' of graph 149 misses edges.
# Node 'Node 1' of graph 150 misses edges.
# Node 'Node 2' of graph 150 misses edges.
# Node 'Node 1' of graph 151 misses edges.
# Node 'Node 2' of graph 151 misses edges.
# Node 'Node 1' of graph 152 misses edges.
# Node 'Node 2' of graph 152 misses edges.
# Node 'Node 1' of graph 153 misses edges.
# Node 'Node 2' of graph 153 misses edges.
# Node 'Node 1' of graph 154 misses edges.
# Node 'Node 2' of graph 154 misses edges.
# Node 'Node 1' of graph 155 misses edges.
# Node 'Node 2' of graph 155 misses edges.
# Node 'Node 1' of graph 156 misses edges.
# Node 'Node 2' of graph 156 misses edges.
# Node 'Node 1' of graph 157 misses edges.
# Node 'Node 2' of graph 157 misses edges.
# Node 'Node 1' of graph 158 misses edges.
# Node 'Node 2' of graph 158 misses edges.
# Node 'Node 1' of graph 159 misses edges.
# Node 'Node 2' of graph 159 misses edges.
# Node 'Node 1' of graph 160 misses edges.
# Node 'Node 2' of graph 160 misses edges.
# Node 'Node 1' of graph 161 misses edges.
# Node 'Node 2' of graph 161 misses edges.
# Node 'Node 1' of graph 162 misses edges.
# Node 'Node 2' of graph 162 misses edges.
# Node 'Node 1' of graph 163 misses edges.
# Node 'Node 2' of graph 163 misses edges.
# Node 'Node 1' of graph 164 misses edges.
# Node 'Node 2' of graph 164 misses edges.
# Node 'Node 1' of graph 165 misses edges.
# Node 'Node 2' of graph 165 misses edges.
# Node 'Node 1' of graph 166 misses edges.
# Node 'Node 2' of graph 166 misses edges.
# Node 'Node 1' of graph 167 misses edges.
# Node 'Node 2' of graph 167 misses edges.
# Node 'Node 1' of graph 168 misses edges.
# Node 'Node 2' of graph 168 misses edges.
# Node 'Node 1' of graph 169 misses edges.
# Node 'Node 2' of graph 169 misses edges.
# Node 'Node 1' of graph 170 misses edges.
# Node 'Node 2' of graph 170 misses edges.
# Node 'Node 1' of graph 171 misses edges.
# Node 'Node 2' of graph 171 misses edges.
# Node 'Node 1' of graph 172 misses edges.
# Node 'Node 2' of graph 172 misses edges.
# Node 'Node 1' of graph 173 misses edges.
# Node 'Node 2' of graph 173 misses edges.
# Node 'Node 1' of graph 174 misses edges.
# Node 'Node 2' of graph 174 misses edges.
# Node 'Node 1' of graph 175 misses edges.
# Node 'Node 2' of graph 175 misses edges.
# Node 'Node 1' of graph 176 misses edges.
# Node 'Node 2' of graph 176 misses edges.
# Node 'Node 1' of graph 177 misses edges.
# Node 'Node 2' of graph 177 misses edges.
# Node 'Node 1' of graph 178 misses edges.
# Node 'Node 2' of graph 178 misses edges.
# Node 'Node 1' of graph 179 misses edges.
# Node 'Node 2' of graph 179 misses edges.
# Node 'Node 1' of graph 180 misses edges.
# Node 'Node 2' of graph 180 misses edges.
# Node 'Node 1' of graph 181 misses edges.
# Node 'Node 2' of graph 181 misses edges.
# Node 'Node 1' of graph 182 misses edges.
# Node 'Node 2' of graph 182 misses edges.
# Node 'Node 1' of graph 183 misses edges.
# Node 'Node 2' of graph 183 misses edges.
# Node 'Node 1' of graph 184 misses edges.
# Node 'Node 2' of graph 184 misses edges.
# Node 'Node 1' of graph 185 misses edges.
# Node 'Node 2' of graph 185 misses edges.
# Node 'Node 1' of graph 186 misses edges.
# Node 'Node 2' of graph 186 misses edges.
# Node 'Node 1' of graph 187 misses edges.
# Node 'Node 2' of graph 187 misses edges.
# Node 'Node 1' of graph 188 misses edges.
# Node 'Node 2' of graph 188 misses edges.
# Node 'Node 1' of graph 189 misses edges.
# Node 'Node 2' of graph 189 misses edges.
# Node 'Node 1' of graph 190 misses edges.
# Node 'Node 2' of graph 190 misses edges.
# Node 'Node 1' of graph 191 misses edges.
# Node 'Node 2' of graph 191 misses edges.
# Node 'Node 1' of graph 192 misses edges.
# Node 'Node 2' of graph 192 misses edges.
# Node 'Node 1' of graph 193 misses edges.
# Node 'Node 2' of graph 193 misses edges.
# Node 'Node 1' of graph 194 misses edges.
# Node 'Node 2' of graph 194 misses edges.
# Node 'Node 1' of graph 195 misses edges.
# Node 'Node 2' of graph 195 misses edges.
# Node 'Node 1' of graph 196 misses edges.
# Node 'Node 2' of graph 196 misses edges.
# Node 'Node 1' of graph 197 misses edges.
# Node 'Node 2' of graph 197 misses edges.
# Node 'Node 1' of graph 198 misses edges.
# Node 'Node 2' of graph 198 misses edges.
# Node 'Node 1' of graph 199 misses edges.
# Node 'Node 2' of graph 199 misses edges.
# Node 'Node 1' of graph 200 misses edges.
# Node 'Node 2' of graph 200 misses edges.
# Node 'Node 1' of graph 201 misses edges.
# Node 'Node 2' of graph 201 misses edges.
# Node 'Node 1' of graph 202 misses edges.
# Node 'Node 2' of graph 202 misses edges.
# Node 'Node 1' of graph 203 misses edges.
# Node 'Node 2' of graph 203 misses edges.
# Node 'Node 1' of graph 204 misses edges.
# Node 'Node 2' of graph 204 misses edges.
# Node 'Node 1' of graph 205 misses edges.
# Node 'Node 2' of graph 205 misses edges.
# Node 'Node 1' of graph 206 misses edges.
# Node 'Node 2' of graph 206 misses edges.
# Node 'Node 1' of graph 207 misses edges.
# Node 'Node 2' of graph 207 misses edges.
# Node 'Node 1' of graph 208 misses edges.
# Node 'Node 2' of graph 208 misses edges.
# Node 'Node 1' of graph 209 misses edges.
# Node 'Node 2' of graph 209 misses edges.
# Node 'Node 1' of graph 210 misses edges.
# Node 'Node 2' of graph 210 misses edges.
# Node 'Node 1' of graph 211 misses edges.
# Node 'Node 2' of graph 211 misses edges.
# Node 'Node 1' of graph 212 misses edges.
# Node 'Node 2' of graph 212 misses edges.
# Node 'Node 1' of graph 213 misses edges.
# Node 'Node 2' of graph 213 misses edges.
# Node 'Node 1' of graph 214 misses edges.
# Node 'Node 2' of graph 214 misses edges.
# Node 'Node 1' of graph 215 misses edges.
# Node 'Node 2' of graph 215 misses edges.
# Node 'Node 1' of graph 216 misses edges.
# Node 'Node 2' of graph 216 misses edges.
# Node 'Node 1' of graph 217 misses edges.
# Node 'Node 2' of graph 217 misses edges.
# Node 'Node 1' of graph 218 misses edges.
# Node 'Node 2' of graph 218 misses edges.
# Node 'Node 1' of graph 219 misses edges.
# Node 'Node 2' of graph 219 misses edges.
# Node 'Node 1' of graph 220 misses edges.
# Node 'Node 2' of graph 220 misses edges.
# Node 'Node 1' of graph 221 misses edges.
# Node 'Node 2' of graph 221 misses edges.
# Node 'Node 1' of graph 222 misses edges.
# Node 'Node 2' of graph 222 misses edges.
# Node 'Node 1' of graph 223 misses edges.
# Node 'Node 2' of graph 223 misses edges.
# Node 'Node 1' of graph 224 misses edges.
# Node 'Node 2' of graph 224 misses edges.
# Node 'Node 1' of graph 225 misses edges.
# Node 'Node 2' of graph 225 misses edges.
# Node 'Node 1' of graph 226 misses edges.
# Node 'Node 2' of graph 226 misses edges.
# Node 'Node 1' of graph 227 misses edges.
# Node 'Node 2' of graph 227 misses edges.
# Node 'Node 1' of graph 228 misses edges.
# Node 'Node 2' of graph 228 misses edges.
# Node 'Node 1' of graph 229 misses edges.
# Node 'Node 2' of graph 229 misses edges.
# Node 'Node 1' of graph 230 misses edges.
# Node 'Node 2' of graph 230 misses edges.
# Node 'Node 1' of graph 231 misses edges.
# Node 'Node 2' of graph 231 misses edges.
# Node 'Node 1' of graph 232 misses edges.
# Node 'Node 2' of graph 232 misses edges.
# Node 'Node 1' of graph 233 misses edges.
# Node 'Node 2' of graph 233 misses edges.
# Node 'Node 1' of graph 234 misses edges.
# Node 'Node 2' of graph 234 misses edges.
# Node 'Node 1' of graph 235 misses edges.
# Node 'Node 2' of graph 235 misses edges.
# Node 'Node 1' of graph 236 misses edges.
# Node 'Node 2' of graph 236 misses edges.
# Node 'Node 1' of graph 237 misses edges.
# Node 'Node 2' of graph 237 misses edges.
# Node 'Node 1' of graph 238 misses edges.
# Node 'Node 2' of graph 238 misses edges.
# Node 'Node 1' of graph 239 misses edges.
# Node 'Node 2' of graph 239 misses edges.
# Node 'Node 1' of graph 240 misses edges.
# Node 'Node 2' of graph 240 misses edges.
# Node 'Node 1' of graph 241 misses edges.
# Node 'Node 2' of graph 241 misses edges.
# Node 'Node 1' of graph 242 misses edges.
# Node 'Node 2' of graph 242 misses edges.
# Node 'Node 1' of graph 243 misses edges.
# Node 'Node 2' of graph 243 misses edges.
# Node 'Node 1' of graph 244 misses edges.
# Node 'Node 2' of graph 244 misses edges.
# Node 'Node 1' of graph 245 misses edges.
# Node 'Node 2' of graph 245 misses edges.
# Node 'Node 1' of graph 246 misses edges.
# Node 'Node 2' of graph 246 misses edges.
# Node 'Node 1' of graph 247 misses edges.
# Node 'Node 2' of graph 247 misses edges.
# Node 'Node 1' of graph 248 misses edges.
# Node 'Node 2' of graph 248 misses edges.
# Node 'Node 1' of graph 249 misses edges.
# Node 'Node 2' of graph 249 misses edges.
# Node 'Node 1' of graph 250 misses edges.
# Node 'Node 2' of graph 250 misses edges.
# Node 'Node 1' of graph 251 misses edges.
# Node 'Node 2' of graph 251 misses edges.
# Node 'Node 1' of graph 252 misses edges.
# Node 'Node 2' of graph 252 misses edges.
# Node 'Node 1' of graph 253 misses edges.
# Node 'Node 2' of graph 253 misses edges.
# Node 'Node 1' of graph 254 misses edges.
# Node 'Node 2' of graph 254 misses edges.
# Node 'Node 1' of graph 255 misses edges.
# Node 'Node 2' of graph 255 misses edges.
# Node 'Node 1' of graph 256 misses edges.
# Node 'Node 2' of graph 256 misses edges.
# Node 'Node 1' of graph 257 misses edges.
# Node 'Node 2' of graph 257 misses edges.
# Node 'Node 1' of graph 258 misses edges.
# Node 'Node 2' of graph 258 misses edges.
# Node 'Node 1' of graph 259 misses edges.
# Node 'Node 2' of graph 259 misses edges.
# Node 'Node 1' of graph 260 misses edges.
# Node 'Node 2' of graph 260 misses edges.
# Node 'Node 1' of graph 261 misses edges.
# Node 'Node 2' of graph 261 misses edges.
# Node 'Node 1' of graph 262 misses edges.
# Node 'Node 2' of graph 262 misses edges.
# Node 'Node 1' of graph 263 misses edges.
# Node 'Node 2' of graph 263 misses edges.
# Node 'Node 1' of graph 264 misses edges.
# Node 'Node 2' of graph 264 misses edges.
# Node 'Node 1' of graph 265 misses edges.
# Node 'Node 2' of graph 265 misses edges.
# Node 'Node 1' of graph 266 misses edges.
# Node 'Node 2' of graph 266 misses edges.
# Node 'Node 1' of graph 267 misses edges.
# Node 'Node 2' of graph 267 misses edges.
# Node 'Node 1' of graph 268 misses edges.
# Node 'Node 2' of graph 268 misses edges.
# Node 'Node 1' of graph 269 misses edges.
# Node 'Node 2' of graph 269 misses edges.
# Node 'Node 1' of graph 270 misses edges.
# Node 'Node 2' of graph 270 misses edges.
# Node 'Node 1' of graph 271 misses edges.
# Node 'Node 2' of graph 271 misses edges.
# Node 'Node 1' of graph 272 misses edges.
# Node 'Node 2' of graph 272 misses edges.
# Node 'Node 1' of graph 273 misses edges.
# Node 'Node 2' of graph 273 misses edges.
# Node 'Node 1' of graph 274 misses edges.
# Node 'Node 2' of graph 274 misses edges.
# Node 'Node 1' of graph 275 misses edges.
# Node 'Node 2' of graph 275 misses edges.
# Node 'Node 1' of graph 276 misses edges.
# Node 'Node 2' of graph 276 misses edges.
# Node 'Node 1' of graph 277 misses edges.
# Node 'Node 2' of graph 277 misses edges.
# Node 'Node 1' of graph 278 misses edges.
# Node 'Node 2' of graph 278 misses edges.
# Node 'Node 1' of graph 279 misses edges.
# Node 'Node 2' of graph 279 misses edges.
# Node 'Node 1' of graph 280 misses edges.
# Node 'Node 2' of graph 280 misses edges.
# Node 'Node 1' of graph 281 misses edges.
# Node 'Node 2' of graph 281 misses edges.
# Node 'Node 1' of graph 282 misses edges.
# Node 'Node 2' of graph 282 misses edges.
# Node 'Node 1' of graph 283 misses edges.
# Node 'Node 2' of graph 283 misses edges.
# Node 'Node 1' of graph 284 misses edges.
# Node 'Node 2' of graph 284 misses edges.
# Node 'Node 1' of graph 285 misses edges.
# Node 'Node 2' of graph 285 misses edges.
# Node 'Node 1' of graph 286 misses edges.
# Node 'Node 2' of graph 286 misses edges.
# Node 'Node 1' of graph 287 misses edges.
# Node 'Node 2' of graph 287 misses edges.
# Node 'Node 1' of graph 288 misses edges.
# Node 'Node 2' of graph 288 misses edges.
# Node 'Node 1' of graph 289 misses edges.
# Node 'Node 2' of graph 289 misses edges.
# Node 'Node 1' of graph 290 misses edges.
# Node 'Node 2' of graph 290 misses edges.
# Node 'Node 1' of graph 291 misses edges.
# Node 'Node 2' of graph 291 misses edges.
# Node 'Node 1' of graph 292 misses edges.
# Node 'Node 2' of graph 292 misses edges.
# Node 'Node 1' of graph 293 misses edges.
# Node 'Node 2' of graph 293 misses edges.
# Node 'Node 1' of graph 294 misses edges.
# Node 'Node 2' of graph 294 misses edges.
# Node 'Node 1' of graph 295 misses edges.
# Node 'Node 2' of graph 295 misses edges.
# Node 'Node 1' of graph 296 misses edges.
# Node 'Node 2' of graph 296 misses edges.
# Node 'Node 1' of graph 297 misses edges.
# Node 'Node 2' of graph 297 misses edges.
# Node 'Node 1' of graph 298 misses edges.
# Node 'Node 2' of graph 298 misses edges.
# Node 'Node 1' of graph 299 misses edges.
# Node 'Node 2' of graph 299 misses edges.
# Node 'Node 1' of graph 300 misses edges.
# Node 'Node 2' of graph 300 misses edges.
# Node 'Node 1' of graph 301 misses edges.
# Node 'Node 2' of graph 301 misses edges.
# Node 'Node 1' of graph 302 misses edges.
# Node 'Node 2' of graph 302 misses edges.
# Node 'Node 1' of graph 303 misses edges.
# Node 'Node 2' of graph 303 misses edges.
# Node 'Node 1' of graph 304 misses edges.
# Node 'Node 2' of graph 304 misses edges.
# Node 'Node 1' of graph 305 misses edges.
# Node 'Node 2' of graph 305 misses edges.
# Node 'Node 1' of graph 306 misses edges.
# Node 'Node 2' of graph 306 misses edges.
# Node 'Node 1' of graph 307 misses edges.
# Node 'Node 2' of graph 307 misses edges.
# Node 'Node 1' of graph 308 misses edges.
# Node 'Node 2' of graph 308 misses edges.
# Node 'Node 1' of graph 309 misses edges.
# Node 'Node 2' of graph 309 misses edges.
# Node 'Node 1' of graph 310 misses edges.
# Node 'Node 2' of graph 310 misses edges.
# Node 'Node 1' of graph 311 misses edges.
# Node 'Node 2' of graph 311 misses edges.
# Node 'Node 1' of graph 312 misses edges.
# Node 'Node 2' of graph 312 misses edges.
# Node 'Node 1' of graph 313 misses edges.
# Node 'Node 2' of graph 313 misses edges.
# Node 'Node 1' of graph 314 misses edges.
# Node 'Node 2' of graph 314 misses edges.
# Node 'Node 1' of graph 315 misses edges.
# Node 'Node 2' of graph 315 misses edges.
# Node 'Node 1' of graph 316 misses edges.
# Node 'Node 2' of graph 316 misses edges.
# Node 'Node 1' of graph 317 misses edges.
# Node 'Node 2' of graph 317 misses edges.
# Node 'Node 1' of graph 318 misses edges.
# Node 'Node 2' of graph 318 misses edges.
# Node 'Node 1' of graph 319 misses edges.
# Node 'Node 2' of graph 319 misses edges.
# Node 'Node 1' of graph 320 misses edges.
# Node 'Node 2' of graph 320 misses edges.
# Node 'Node 1' of graph 321 misses edges.
# Node 'Node 2' of graph 321 misses edges.
# Node 'Node 1' of graph 322 misses edges.
# Node 'Node 2' of graph 322 misses edges.
# Node 'Node 1' of graph 323 misses edges.
# Node 'Node 2' of graph 323 misses edges.
# Node 'Node 1' of graph 324 misses edges.
# Node 'Node 2' of graph 324 misses edges.
# Node 'Node 1' of graph 325 misses edges.
# Node 'Node 2' of graph 325 misses edges.
# Node 'Node 1' of graph 326 misses edges.
# Node 'Node 2' of graph 326 misses edges.
# Node 'Node 1' of graph 327 misses edges.
# Node 'Node 2' of graph 327 misses edges.
# Node 'Node 1' of graph 328 misses edges.
# Node 'Node 2' of graph 328 misses edges.
# Node 'Node 1' of graph 329 misses edges.
# Node 'Node 2' of graph 329 misses edges.
# Node 'Node 1' of graph 330 misses edges.
# Node 'Node 2' of graph 330 misses edges.
# Node 'Node 1' of graph 331 misses edges.
# Node 'Node 2' of graph 331 misses edges.
# Node 'Node 1' of graph 332 misses edges.
# Node 'Node 2' of graph 332 misses edges.
# Node 'Node 1' of graph 333 misses edges.
# Node 'Node 2' of graph 333 misses edges.
# Node 'Node 1' of graph 334 misses edges.
# Node 'Node 2' of graph 334 misses edges.
# Node 'Node 1' of graph 335 misses edges.
# Node 'Node 2' of graph 335 misses edges.
# Node 'Node 1' of graph 336 misses edges.
# Node 'Node 2' of graph 336 misses edges.
# Node 'Node 1' of graph 337 misses edges.
# Node 'Node 2' of graph 337 misses edges.
# Node 'Node 1' of graph 338 misses edges.
# Node 'Node 2' of graph 338 misses edges.
# Node 'Node 1' of graph 339 misses edges.
# Node 'Node 2' of graph 339 misses edges.
# Node 'Node 1' of graph 340 misses edges.
# Node 'Node 2' of graph 340 misses edges.
# Node 'Node 1' of graph 341 misses edges.
# Node 'Node 2' of graph 341 misses edges.
# Node 'Node 1' of graph 342 misses edges.
# Node 'Node 2' of graph 342 misses edges.
# Node 'Node 1' of graph 343 misses edges.
# Node 'Node 2' of graph 343 misses edges.
# Node 'Node 1' of graph 344 misses edges.
# Node 'Node 2' of graph 344 misses edges.
# Node 'Node 1' of graph 345 misses edges.
# Node 'Node 2' of graph 345 misses edges.
# Node 'Node 1' of graph 346 misses edges.
# Node 'Node 2' of graph 346 misses edges.
# Node 'Node 1' of graph 347 misses edges.
# Node 'Node 2' of graph 347 misses edges.
# Node 'Node 1' of graph 348 misses edges.
# Node 'Node 2' of graph 348 misses edges.
# Node 'Node 1' of graph 349 misses edges.
# Node 'Node 2' of graph 349 misses edges.
# Node 'Node 1' of graph 350 misses edges.
# Node 'Node 2' of graph 350 misses edges.
# Node 'Node 1' of graph 351 misses edges.
# Node 'Node 2' of graph 351 misses edges.
# Node 'Node 1' of graph 352 misses edges.
# Node 'Node 2' of graph 352 misses edges.
# Node 'Node 1' of graph 353 misses edges.
# Node 'Node 2' of graph 353 misses edges.
# Node 'Node 1' of graph 354 misses edges.
# Node 'Node 2' of graph 354 misses edges.
# Node 'Node 1' of graph 355 misses edges.
# Node 'Node 2' of graph 355 misses edges.
# Node 'Node 1' of graph 356 misses edges.
# Node 'Node 2' of graph 356 misses edges.
# Node 'Node 1' of graph 357 misses edges.
# Node 'Node 2' of graph 357 misses edges.
# Node 'Node 1' of graph 358 misses edges.
# Node 'Node 2' of graph 358 misses edges.
# Node 'Node 1' of graph 359 misses edges.
# Node 'Node 2' of graph 359 misses edges.
# Node 'Node 1' of graph 360 misses edges.
# Node 'Node 2' of graph 360 misses edges.
# Node 'Node 1' of graph 361 misses edges.
# Node 'Node 2' of graph 361 misses edges.
# Node 'Node 1' of graph 362 misses edges.
# Node 'Node 2' of graph 362 misses edges.
# Node 'Node 1' of graph 363 misses edges.
# Node 'Node 2' of graph 363 misses edges.
# Node 'Node 1' of graph 364 misses edges.
# Node 'Node 2' of graph 364 misses edges.
# Node 'Node 1' of graph 365 misses edges.
# Node 'Node 2' of graph 365 misses edges.
# Node 'Node 1' of graph 366 misses edges.
# Node 'Node 2' of graph 366 misses edges.
# Node 'Node 1' of graph 367 misses edges.
# Node 'Node 2' of graph 367 misses edges.
# Node 'Node 1' of graph 368 misses edges.
# Node 'Node 2' of graph 368 misses edges.
# Node 'Node 1' of graph 369 misses edges.
# Node 'Node 2' of graph 369 misses edges.
# Node 'Node 1' of graph 370 misses edges.
# Node 'Node 2' of graph 370 misses edges.
# Node 'Node 1' of graph 371 misses edges.
# Node 'Node 2' of graph 371 misses edges.
# Node 'Node 1' of graph 372 misses edges.
# Node 'Node 2' of graph 372 misses edges.
# Node 'Node 1' of graph 373 misses edges.
# Node 'Node 2' of graph 373 misses edges.
# Node 'Node 1' of graph 374 misses edges.
# Node 'Node 2' of graph 374 misses edges.
# Node 'Node 1' of graph 375 misses edges.
# Node 'Node 2' of graph 375 misses edges.
# Node 'Node 1' of graph 376 misses edges.
# Node 'Node 2' of graph 376 misses edges.
# Node 'Node 1' of graph 377 misses edges.
# Node 'Node 2' of graph 377 misses edges.
# Node 'Node 1' of graph 378 misses edges.
# Node 'Node 2' of graph 378 misses edges.
# Node 'Node 1' of graph 379 misses edges.
# Node 'Node 2' of graph 379 misses edges.
# Node 'Node 1' of graph 380 misses edges.
# Node 'Node 2' of graph 380 misses edges.
# Node 'Node 1' of graph 381 misses edges.
# Node 'Node 2' of graph 381 misses edges.
# Node 'Node 1' of graph 382 misses edges.
# Node 'Node 2' of graph 382 misses edges.
# Node 'Node 1' of graph 383 misses edges.
# Node 'Node 2' of graph 383 misses edges.
# Node 'Node 1' of graph 384 misses edges.
# Node 'Node 2' of graph 384 misses edges.
# Node 'Node 1' of graph 385 misses edges.
# Node 'Node 2' of graph 385 misses edges.
# Node 'Node 1' of graph 386 misses edges.
# Node 'Node 2' of graph 386 misses edges.
# Node 'Node 1' of graph 387 misses edges.
# Node 'Node 2' of graph 387 misses edges.
# Node 'Node 1' of graph 388 misses edges.
# Node 'Node 2' of graph 388 misses edges.
# Node 'Node 1' of graph 389 misses edges.
# Node 'Node 2' of graph 389 misses edges.
# Node 'Node 1' of graph 390 misses edges.
# Node 'Node 2' of graph 390 misses edges.
# Node 'Node 1' of graph 391 misses edges.
# Node 'Node 2' of graph 391 misses edges.
# Node 'Node 1' of graph 392 misses edges.
# Node 'Node 2' of graph 392 misses edges.
# Node 'Node 1' of graph 393 misses edges.
# Node 'Node 2' of graph 393 misses edges.
# Node 'Node 1' of graph 394 misses edges.
# Node 'Node 2' of graph 394 misses edges.
# Node 'Node 1' of graph 395 misses edges.
# Node 'Node 2' of graph 395 misses edges.
# Node 'Node 1' of graph 396 misses edges.
# Node 'Node 2' of graph 396 misses edges.
# Node 'Node 1' of graph 397 misses edges.
# Node 'Node 2' of graph 397 misses edges.
# Node 'Node 1' of graph 398 misses edges.
# Node 'Node 2' of graph 398 misses edges.
# Node 'Node 1' of graph 399 misses edges.
# Node 'Node 2' of graph 399 misses edges.
# Node 'Node 1' of graph 400 misses edges.
# Node 'Node 2' of graph 400 misses edges.
# Node 'Node 1' of graph 401 misses edges.
# Node 'Node 2' of graph 401 misses edges.
# Node 'Node 1' of graph 402 misses edges.
# Node 'Node 2' of graph 402 misses edges.
# Node 'Node 1' of graph 403 misses edges.
# Node 'Node 2' of graph 403 misses edges.
# Node 'Node 1' of graph 404 misses edges.
# Node 'Node 2' of graph 404 misses edges.
# Node 'Node 1' of graph 405 misses edges.
# Node 'Node 2' of graph 405 misses edges.
# Node 'Node 1' of graph 406 misses edges.
# Node 'Node 2' of graph 406 misses edges.
# Node 'Node 1' of graph 407 misses edges.
# Node 'Node 2' of graph 407 misses edges.
# Node 'Node 1' of graph 408 misses edges.
# Node 'Node 2' of graph 408 misses edges.
# Node 'Node 1' of graph 409 misses edges.
# Node 'Node 2' of graph 409 misses edges.
# Node 'Node 1' of graph 410 misses edges.
# Node 'Node 2' of graph 410 misses edges.
# Node 'Node 1' of graph 411 misses edges.
# Node 'Node 2' of graph 411 misses edges.
# Node 'Node 1' of graph 412 misses edges.
# Node 'Node 2' of graph 412 misses edges.
# Node 'Node 1' of graph 413 misses edges.
# Node 'Node 2' of graph 413 misses edges.
# Node 'Node 1' of graph 414 misses edges.
# Node 'Node 2' of graph 414 misses edges.
# Node 'Node 1' of graph 415 misses edges.
# Node 'Node 2' of graph 415 misses edges.
# Node 'Node 1' of graph 416 misses edges.
# Node 'Node 2' of graph 416 misses edges.
# Node 'Node 1' of graph 417 misses edges.
# Node 'Node 2' of graph 417 misses edges.
# Node 'Node 1' of graph 418 misses edges.
# Node 'Node 2' of graph 418 misses edges.
# Node 'Node 1' of graph 419 misses edges.
# Node 'Node 2' of graph 419 misses edges.
# Node 'Node 1' of graph 420 misses edges.
# Node 'Node 2' of graph 420 misses edges.
# Node 'Node 1' of graph 421 misses edges.
# Node 'Node 2' of graph 421 misses edges.
# Node 'Node 1' of graph 422 misses edges.
# Node 'Node 2' of graph 422 misses edges.
# Node 'Node 1' of graph 423 misses edges.
# Node 'Node 2' of graph 423 misses edges.
# Node 'Node 1' of graph 424 misses edges.
# Node 'Node 2' of graph 424 misses edges.
# Node 'Node 1' of graph 425 misses edges.
# Node 'Node 2' of graph 425 misses edges.
# Node 'Node 1' of graph 426 misses edges.
# Node 'Node 2' of graph 426 misses edges.
# Node 'Node 1' of graph 427 misses edges.
# Node 'Node 2' of graph 427 misses edges.
# Node 'Node 1' of graph 428 misses edges.
# Node 'Node 2' of graph 428 misses edges.
# Node 'Node 1' of graph 429 misses edges.
# Node 'Node 2' of graph 429 misses edges.
# Node 'Node 1' of graph 430 misses edges.
# Node 'Node 2' of graph 430 misses edges.
# Node 'Node 1' of graph 431 misses edges.
# Node 'Node 2' of graph 431 misses edges.
# Node 'Node 1' of graph 432 misses edges.
# Node 'Node 2' of graph 432 misses edges.
# Node 'Node 1' of graph 433 misses edges.
# Node 'Node 2' of graph 433 misses edges.
# Node 'Node 1' of graph 434 misses edges.
# Node 'Node 2' of graph 434 misses edges.
# Node 'Node 1' of graph 435 misses edges.
# Node 'Node 2' of graph 435 misses edges.
# Node 'Node 1' of graph 436 misses edges.
# Node 'Node 2' of graph 436 misses edges.
# Node 'Node 1' of graph 437 misses edges.
# Node 'Node 2' of graph 437 misses edges.
# Node 'Node 1' of graph 438 misses edges.
# Node 'Node 2' of graph 438 misses edges.
# Node 'Node 1' of graph 439 misses edges.
# Node 'Node 2' of graph 439 misses edges.
# Node 'Node 1' of graph 440 misses edges.
# Node 'Node 2' of graph 440 misses edges.
# Node 'Node 1' of graph 441 misses edges.
# Node 'Node 2' of graph 441 misses edges.
# Node 'Node 1' of graph 442 misses edges.
# Node 'Node 2' of graph 442 misses edges.
# Node 'Node 1' of graph 443 misses edges.
# Node 'Node 2' of graph 443 misses edges.
# Node 'Node 1' of graph 444 misses edges.
# Node 'Node 2' of graph 444 misses edges.
# Node 'Node 1' of graph 445 misses edges.
# Node 'Node 2' of graph 445 misses edges.
# Node 'Node 1' of graph 446 misses edges.
# Node 'Node 2' of graph 446 misses edges.
# Node 'Node 1' of graph 447 misses edges.
# Node 'Node 2' of graph 447 misses edges.
# Node 'Node 1' of graph 448 misses edges.
# Node 'Node 2' of graph 448 misses edges.
# Node 'Node 1' of graph 449 misses edges.
# Node 'Node 2' of graph 449 misses edges.
# Node 'Node 1' of graph 450 misses edges.
# Node 'Node 2' of graph 450 misses edges.
# Node 'Node 1' of graph 451 misses edges.
# Node 'Node 2' of graph 451 misses edges.
# Node 'Node 1' of graph 452 misses edges.
# Node 'Node 2' of graph 452 misses edges.
# Node 'Node 1' of graph 453 misses edges.
# Node 'Node 2' of graph 453 misses edges.
# Node 'Node 1' of graph 454 misses edges.
# Node 'Node 2' of graph 454 misses edges.
# Node 'Node 1' of graph 455 misses edges.
# Node 'Node 2' of graph 455 misses edges.
# Node 'Node 1' of graph 456 misses edges.
# Node 'Node 2' of graph 456 misses edges.
# Node 'Node 1' of graph 457 misses edges.
# Node 'Node 2' of graph 457 misses edges.
# Node 'Node 1' of graph 458 misses edges.
# Node 'Node 2' of graph 458 misses edges.
# Node 'Node 1' of graph 459 misses edges.
# Node 'Node 2' of graph 459 misses edges.
# Node 'Node 1' of graph 460 misses edges.
# Node 'Node 2' of graph 460 misses edges.
# Node 'Node 1' of graph 461 misses edges.
# Node 'Node 2' of graph 461 misses edges.
# Node 'Node 1' of graph 462 misses edges.
# Node 'Node 2' of graph 462 misses edges.
# Node 'Node 1' of graph 463 misses edges.
# Node 'Node 2' of graph 463 misses edges.
# Node 'Node 1' of graph 464 misses edges.
# Node 'Node 2' of graph 464 misses edges.
# Node 'Node 1' of graph 465 misses edges.
# Node 'Node 2' of graph 465 misses edges.
# Node 'Node 1' of graph 466 misses edges.
# Node 'Node 2' of graph 466 misses edges.
# Node 'Node 1' of graph 467 misses edges.
# Node 'Node 2' of graph 467 misses edges.
# Node 'Node 1' of graph 468 misses edges.
# Node 'Node 2' of graph 468 misses edges.
# Node 'Node 1' of graph 469 misses edges.
# Node 'Node 2' of graph 469 misses edges.
# Node 'Node 1' of graph 470 misses edges.
# Node 'Node 2' of graph 470 misses edges.
# Node 'Node 1' of graph 471 misses edges.
# Node 'Node 2' of graph 471 misses edges.
# Node 'Node 1' of graph 472 misses edges.
# Node 'Node 2' of graph 472 misses edges.
# Node 'Node 1' of graph 473 misses edges.
# Node 'Node 2' of graph 473 misses edges.
# Node 'Node 1' of graph 474 misses edges.
# Node 'Node 2' of graph 474 misses edges.
# Node 'Node 1' of graph 475 misses edges.
# Node 'Node 2' of graph 475 misses edges.
# Node 'Node 1' of graph 476 misses edges.
# Node 'Node 2' of graph 476 misses edges.
# Node 'Node 1' of graph 477 misses edges.
# Node 'Node 2' of graph 477 misses edges.
# Node 'Node 1' of graph 478 misses edges.
# Node 'Node 2' of graph 478 misses edges.
# Node 'Node 1' of graph 479 misses edges.
# Node 'Node 2' of graph 479 misses edges.
# Node 'Node 1' of graph 480 misses edges.
# Node 'Node 2' of graph 480 misses edges.
# Node 'Node 1' of graph 481 misses edges.
# Node 'Node 2' of graph 481 misses edges.
# Node 'Node 1' of graph 482 misses edges.
# Node 'Node 2' of graph 482 misses edges.
# Node 'Node 1' of graph 483 misses edges.
# Node 'Node 2' of graph 483 misses edges.
# Node 'Node 1' of graph 484 misses edges.
# Node 'Node 2' of graph 484 misses edges.
# Node 'Node 1' of graph 485 misses edges.
# Node 'Node 2' of graph 485 misses edges.
# Node 'Node 1' of graph 486 misses edges.
# Node 'Node 2' of graph 486 misses edges.
# Node 'Node 1' of graph 487 misses edges.
# Node 'Node 2' of graph 487 misses edges.
# Node 'Node 1' of graph 488 misses edges.
# Node 'Node 2' of graph 488 misses edges.
# Node 'Node 1' of graph 489 misses edges.
# Node 'Node 2' of graph 489 misses edges.
# Node 'Node 1' of graph 490 misses edges.
# Node 'Node 2' of graph 490 misses edges.
# Node 'Node 1' of graph 491 misses edges.
# Node 'Node 2' of graph 491 misses edges.
# Node 'Node 1' of graph 492 misses edges.
# Node 'Node 2' of graph 492 misses edges.
# Node 'Node 1' of graph 493 misses edges.
# Node 'Node 2' of graph 493 misses edges.
# Node 'Node 1' of graph 494 misses edges.
# Node 'Node 2' of graph 494 misses edges.
# Node 'Node 1' of graph 495 misses edges.
# Node 'Node 2' of graph 495 misses edges.
# Node 'Node 1' of graph 496 misses edges.
# Node 'Node 2' of graph 496 misses edges.
# Node 'Node 1' of graph 497 misses edges.
# Node 'Node 2' of graph 497 misses edges.
# Node 'Node 1' of graph 498 misses edges.
# Node 'Node 2' of graph 498 misses edges.
# Node 'Node 1' of graph 499 misses edges.
# Node 'Node 2' of graph 499 misses edges.
# Node 'Node 1' of graph 500 misses edges.
# Node 'Node 2' of graph 500 misses edges.
# Node 'Node 1' of graph 501 misses edges.
# Node 'Node 2' of graph 501 misses edges.
# Node 'Node 1' of graph 502 misses edges.
# Node 'Node 2' of graph 502 misses edges.
# Node 'Node 1' of graph 503 misses edges.
# Node 'Node 2' of graph 503 misses edges.
# Node 'Node 1' of graph 504 misses edges.
# Node 'Node 2' of graph 504 misses edges.
# Node 'Node 1' of graph 505 misses edges.
# Node 'Node 2' of graph 505 misses edges.
# Node 'Node 1' of graph 506 misses edges.
# Node 'Node 2' of graph 506 misses edges.
# Node 'Node 1' of graph 507 misses edges.
# Node 'Node 2' of graph 507 misses edges.
# Node 'Node 1' of graph 508 misses edges.
# Node 'Node 2' of graph 508 misses edges.
# Node 'Node 1' of graph 509 misses edges.
# Node 'Node 2' of graph 509 misses edges.
# Node 'Node 1' of graph 510 misses edges.
# Node 'Node 2' of graph 510 misses edges.
# Node 'Node 1' of graph 511 misses edges.
# Node 'Node 2' of graph 511 misses edges.
# Node 'Node 1' of graph 512 misses edges.
# Node 'Node 2' of graph 512 misses edges.
# Node 'Node 1' of graph 513 misses edges.
# Node 'Node 2' of graph 513 misses edges.
# Node 'Node 1' of graph 514 misses edges.
# Node 'Node 2' of graph 514 misses edges.
# Node 'Node 1' of graph 515 misses edges.
# Node 'Node 2' of graph 515 misses edges.
# Node 'Node 1' of graph 516 misses edges.
# Node 'Node 2' of graph 516 misses edges.
# Node 'Node 1' of graph 517 misses edges.
# Node 'Node 2' of graph 517 misses edges.
# Node 'Node 1' of graph 518 misses edges.
# Node 'Node 2' of graph 518 misses edges.
# Node 'Node 1' of graph 519 misses edges.
# Node 'Node 2' of graph 519 misses edges.
# Node 'Node 1' of graph 520 misses edges.
# Node 'Node 2' of graph 520 misses edges.
# Node 'Node 1' of graph 521 misses edges.
# Node 'Node 2' of graph 521 misses edges.
# Node 'Node 1' of graph 522 misses edges.
# Node 'Node 2' of graph 522 misses edges.
# Node 'Node 1' of graph 523 misses edges.
# Node 'Node 2' of graph 523 misses edges.
# Node 'Node 1' of graph 524 misses edges.
# Node 'Node 2' of graph 524 misses edges.
# Node 'Node 1' of graph 525 misses edges.
# Node 'Node 2' of graph 525 misses edges.
# Node 'Node 1' of graph 526 misses edges.
# Node 'Node 2' of graph 526 misses edges.
# Node 'Node 1' of graph 527 misses edges.
# Node 'Node 2' of graph 527 misses edges.
# Node 'Node 1' of graph 528 misses edges.
# Node 'Node 2' of graph 528 misses edges.
# Node 'Node 1' of graph 529 misses edges.
# Node 'Node 2' of graph 529 misses edges.
# Node 'Node 1' of graph 530 misses edges.
# Node 'Node 2' of graph 530 misses edges.
# Node 'Node 1' of graph 531 misses edges.
# Node 'Node 2' of graph 531 misses edges.
# Node 'Node 1' of graph 532 misses edges.
# Node 'Node 2' of graph 532 misses edges.
# Node 'Node 1' of graph 533 misses edges.
# Node 'Node 2' of graph 533 misses edges.
# Node 'Node 1' of graph 534 misses edges.
# Node 'Node 2' of graph 534 misses edges.
# Node 'Node 1' of graph 535 misses edges.
# Node 'Node 2' of graph 535 misses edges.
# Node 'Node 1' of graph 536 misses edges.
# Node 'Node 2' of graph 536 misses edges.
# Node 'Node 1' of graph 537 misses edges.
# Node 'Node 2' of graph 537 misses edges.
# Node 'Node 1' of graph 538 misses edges.
# Node 'Node 2' of graph 538 misses edges.
# Node 'Node 1' of graph 539 misses edges.
# Node 'Node 2' of graph 539 misses edges.
# Node 'Node 1' of graph 540 misses edges.
# Node 'Node 2' of graph 540 misses edges.
# Node 'Node 1' of graph 541 misses edges.
# Node 'Node 2' of graph 541 misses edges.
# Node 'Node 1' of graph 542 misses edges.
# Node 'Node 2' of graph 542 misses edges.
# Node 'Node 1' of graph 543 misses edges.
# Node 'Node 2' of graph 543 misses edges.
# Node 'Node 1' of graph 544 misses edges.
# Node 'Node 2' of graph 544 misses edges.
# Node 'Node 1' of graph 545 misses edges.
# Node 'Node 2' of graph 545 misses edges.
# Node 'Node 1' of graph 546 misses edges.
# Node 'Node 2' of graph 546 misses edges.
# Node 'Node 1' of graph 547 misses edges.
# Node 'Node 2' of graph 547 misses edges.
# Node 'Node 1' of graph 548 misses edges.
# Node 'Node 2' of graph 548 misses edges.
# Node 'Node 1' of graph 549 misses edges.
# Node 'Node 2' of graph 549 misses edges.
# Node 'Node 1' of graph 550 misses edges.
# Node 'Node 2' of graph 550 misses edges.
# Node 'Node 1' of graph 551 misses edges.
# Node 'Node 2' of graph 551 misses edges.
# Node 'Node 1' of graph 552 misses edges.
# Node 'Node 2' of graph 552 misses edges.
# Node 'Node 1' of graph 553 misses edges.
# Node 'Node 2' of graph 553 misses edges.
# Node 'Node 1' of graph 554 misses edges.
# Node 'Node 2' of graph 554 misses edges.
# Node 'Node 1' of graph 555 misses edges.
# Node 'Node 2' of graph 555 misses edges.
# Node 'Node 1' of graph 556 misses edges.
# Node 'Node 2' of graph 556 misses edges.
# Node 'Node 1' of graph 557 misses edges.
# Node 'Node 2' of graph 557 misses edges.
# Node 'Node 1' of graph 558 misses edges.
# Node 'Node 2' of graph 558 misses edges.
# Node 'Node 1' of graph 559 misses edges.
# Node 'Node 2' of graph 559 misses edges.
# Node 'Node 1' of graph 560 misses edges.
# Node 'Node 2' of graph 560 misses edges.
# Node 'Node 1' of graph 561 misses edges.
# Node 'Node 2' of graph 561 misses edges.
# Node 'Node 1' of graph 562 misses edges.
# Node 'Node 2' of graph 562 misses edges.
# Node 'Node 1' of graph 563 misses edges.
# Node 'Node 2' of graph 563 misses edges.
# Node 'Node 1' of graph 564 misses edges.
# Node 'Node 2' of graph 564 misses edges.
# Node 'Node 1' of graph 565 misses edges.
# Node 'Node 2' of graph 565 misses edges.
# Node 'Node 1' of graph 566 misses edges.
# Node 'Node 2' of graph 566 misses edges.
# Node 'Node 1' of graph 567 misses edges.
# Node 'Node 2' of graph 567 misses edges.
# Node 'Node 1' of graph 568 misses edges.
# Node 'Node 2' of graph 568 misses edges.
# Node 'Node 1' of graph 569 misses edges.
# Node 'Node 2' of graph 569 misses edges.
# Node 'Node 1' of graph 570 misses edges.
# Node 'Node 2' of graph 570 misses edges.
# Node 'Node 1' of graph 571 misses edges.
# Node 'Node 2' of graph 571 misses edges.
# Node 'Node 1' of graph 572 misses edges.
# Node 'Node 2' of graph 572 misses edges.
# Node 'Node 1' of graph 573 misses edges.
# Node 'Node 2' of graph 573 misses edges.
# Node 'Node 1' of graph 574 misses edges.
# Node 'Node 2' of graph 574 misses edges.
# Node 'Node 1' of graph 575 misses edges.
# Node 'Node 2' of graph 575 misses edges.
# Node 'Node 1' of graph 576 misses edges.
# Node 'Node 2' of graph 576 misses edges.
# Node 'Node 1' of graph 577 misses edges.
# Node 'Node 2' of graph 577 misses edges.
# Node 'Node 1' of graph 578 misses edges.
# Node 'Node 2' of graph 578 misses edges.
# Node 'Node 1' of graph 579 misses edges.
# Node 'Node 2' of graph 579 misses edges.
# Node 'Node 1' of graph 580 misses edges.
# Node 'Node 2' of graph 580 misses edges.
# Node 'Node 1' of graph 581 misses edges.
# Node 'Node 2' of graph 581 misses edges.
# Node 'Node 1' of graph 582 misses edges.
# Node 'Node 2' of graph 582 misses edges.
# Node 'Node 1' of graph 583 misses edges.
# Node 'Node 2' of graph 583 misses edges.
# Node 'Node 1' of graph 584 misses edges.
# Node 'Node 2' of graph 584 misses edges.
# Node 'Node 1' of graph 585 misses edges.
# Node 'Node 2' of graph 585 misses edges.
# Node 'Node 1' of graph 586 misses edges.
# Node 'Node 2' of graph 586 misses edges.
# Node 'Node 1' of graph 587 misses edges.
# Node 'Node 2' of graph 587 misses edges.
# ...
# Node 'Node 1' of graph 9813 misses edges.
# Node 'Node 2' of graph 9813 misses edges.
# Node 'Node 1' of graph 9814 misses edges.
# Node 'Node 2' of graph 9814 misses edges.
# Node 'Node 1' of graph 9815 misses edges.
# Node 'Node 2' of graph 9815 misses edges.
# Node 'Node 1' of graph 9816 misses edges.
# Node 'Node 2' of graph 9816 misses edges.
# Node 'Node 1' of graph 9817 misses edges.
# Node 'Node 2' of graph 9817 misses edges.
# Node 'Node 1' of graph 9818 misses edges.
# Node 'Node 2' of graph 9818 misses edges.
# Node 'Node 1' of graph 9819 misses edges.
# Node 'Node 2' of graph 9819 misses edges.
# Node 'Node 1' of graph 9820 misses edges.
# Node 'Node 2' of graph 9820 misses edges.
# Node 'Node 1' of graph 9821 misses edges.
# Node 'Node 2' of graph 9821 misses edges.
# Node 'Node 1' of graph 9822 misses edges.
# Node 'Node 2' of graph 9822 misses edges.
# Node 'Node 1' of graph 9823 misses edges.
# Node 'Node 2' of graph 9823 misses edges.
# Node 'Node 1' of graph 9824 misses edges.
# Node 'Node 2' of graph 9824 misses edges.
# Node 'Node 1' of graph 9825 misses edges.
# Node 'Node 2' of graph 9825 misses edges.
# Node 'Node 1' of graph 9826 misses edges.
# Node 'Node 2' of graph 9826 misses edges.
# Node 'Node 1' of graph 9827 misses edges.
# Node 'Node 2' of graph 9827 misses edges.
# Node 'Node 1' of graph 9828 misses edges.
# Node 'Node 2' of graph 9828 misses edges.
# Node 'Node 1' of graph 9829 misses edges.
# Node 'Node 2' of graph 9829 misses edges.
# Node 'Node 1' of graph 9830 misses edges.
# Node 'Node 2' of graph 9830 misses edges.
# Node 'Node 1' of graph 9831 misses edges.
# Node 'Node 2' of graph 9831 misses edges.
# Node 'Node 1' of graph 9832 misses edges.
# Node 'Node 2' of graph 9832 misses edges.
# Node 'Node 1' of graph 9833 misses edges.
# Node 'Node 2' of graph 9833 misses edges.
# Node 'Node 1' of graph 9834 misses edges.
# Node 'Node 2' of graph 9834 misses edges.
# Node 'Node 1' of graph 9835 misses edges.
# Node 'Node 2' of graph 9835 misses edges.
# Node 'Node 1' of graph 9836 misses edges.
# Node 'Node 2' of graph 9836 misses edges.
# Node 'Node 1' of graph 9837 misses edges.
# Node 'Node 2' of graph 9837 misses edges.
# Node 'Node 1' of graph 9838 misses edges.
# Node 'Node 2' of graph 9838 misses edges.
# Node 'Node 1' of graph 9839 misses edges.
# Node 'Node 2' of graph 9839 misses edges.
# Node 'Node 1' of graph 9840 misses edges.
# Node 'Node 2' of graph 9840 misses edges.
# Node 'Node 1' of graph 9841 misses edges.
# Node 'Node 2' of graph 9841 misses edges.
# Node 'Node 1' of graph 9842 misses edges.
# Node 'Node 2' of graph 9842 misses edges.
# Node 'Node 1' of graph 9843 misses edges.
# Node 'Node 2' of graph 9843 misses edges.
# Node 'Node 1' of graph 9844 misses edges.
# Node 'Node 2' of graph 9844 misses edges.
# Node 'Node 1' of graph 9845 misses edges.
# Node 'Node 2' of graph 9845 misses edges.
# Node 'Node 1' of graph 9846 misses edges.
# Node 'Node 2' of graph 9846 misses edges.
# Node 'Node 1' of graph 9847 misses edges.
# Node 'Node 2' of graph 9847 misses edges.
# Node 'Node 1' of graph 9848 misses edges.
# Node 'Node 2' of graph 9848 misses edges.
# Node 'Node 1' of graph 9849 misses edges.
# Node 'Node 2' of graph 9849 misses edges.
# Node 'Node 1' of graph 9850 misses edges.
# Node 'Node 2' of graph 9850 misses edges.
# Node 'Node 1' of graph 9851 misses edges.
# Node 'Node 2' of graph 9851 misses edges.
# Node 'Node 1' of graph 9852 misses edges.
# Node 'Node 2' of graph 9852 misses edges.
# Node 'Node 1' of graph 9853 misses edges.
# Node 'Node 2' of graph 9853 misses edges.
# Node 'Node 1' of graph 9854 misses edges.
# Node 'Node 2' of graph 9854 misses edges.
# Node 'Node 1' of graph 9855 misses edges.
# Node 'Node 2' of graph 9855 misses edges.
# Node 'Node 1' of graph 9856 misses edges.
# Node 'Node 2' of graph 9856 misses edges.
# Node 'Node 1' of graph 9857 misses edges.
# Node 'Node 2' of graph 9857 misses edges.
# Node 'Node 1' of graph 9858 misses edges.
# Node 'Node 2' of graph 9858 misses edges.
# Node 'Node 1' of graph 9859 misses edges.
# Node 'Node 2' of graph 9859 misses edges.
# Node 'Node 1' of graph 9860 misses edges.
# Node 'Node 2' of graph 9860 misses edges.
# Node 'Node 1' of graph 9861 misses edges.
# Node 'Node 2' of graph 9861 misses edges.
# Node 'Node 1' of graph 9862 misses edges.
# Node 'Node 2' of graph 9862 misses edges.
# Node 'Node 1' of graph 9863 misses edges.
# Node 'Node 2' of graph 9863 misses edges.
# Node 'Node 1' of graph 9864 misses edges.
# Node 'Node 2' of graph 9864 misses edges.
# Node 'Node 1' of graph 9865 misses edges.
# Node 'Node 2' of graph 9865 misses edges.
# Node 'Node 1' of graph 9866 misses edges.
# Node 'Node 2' of graph 9866 misses edges.
# Node 'Node 1' of graph 9867 misses edges.
# Node 'Node 2' of graph 9867 misses edges.
# Node 'Node 1' of graph 9868 misses edges.
# Node 'Node 2' of graph 9868 misses edges.
# Node 'Node 1' of graph 9869 misses edges.
# Node 'Node 2' of graph 9869 misses edges.
# Node 'Node 1' of graph 9870 misses edges.
# Node 'Node 2' of graph 9870 misses edges.
# Node 'Node 1' of graph 9871 misses edges.
# Node 'Node 2' of graph 9871 misses edges.
# Node 'Node 1' of graph 9872 misses edges.
# Node 'Node 2' of graph 9872 misses edges.
# Node 'Node 1' of graph 9873 misses edges.
# Node 'Node 2' of graph 9873 misses edges.
# Node 'Node 1' of graph 9874 misses edges.
# Node 'Node 2' of graph 9874 misses edges.
# Node 'Node 1' of graph 9875 misses edges.
# Node 'Node 2' of graph 9875 misses edges.
# Node 'Node 1' of graph 9876 misses edges.
# Node 'Node 2' of graph 9876 misses edges.
# Node 'Node 1' of graph 9877 misses edges.
# Node 'Node 2' of graph 9877 misses edges.
# Node 'Node 1' of graph 9878 misses edges.
# Node 'Node 2' of graph 9878 misses edges.
# Node 'Node 1' of graph 9879 misses edges.
# Node 'Node 2' of graph 9879 misses edges.
# Node 'Node 1' of graph 9880 misses edges.
# Node 'Node 2' of graph 9880 misses edges.
# Node 'Node 1' of graph 9881 misses edges.
# Node 'Node 2' of graph 9881 misses edges.
# Node 'Node 1' of graph 9882 misses edges.
# Node 'Node 2' of graph 9882 misses edges.
# Node 'Node 1' of graph 9883 misses edges.
# Node 'Node 2' of graph 9883 misses edges.
# Node 'Node 1' of graph 9884 misses edges.
# Node 'Node 2' of graph 9884 misses edges.
# Node 'Node 1' of graph 9885 misses edges.
# Node 'Node 2' of graph 9885 misses edges.
# Node 'Node 1' of graph 9886 misses edges.
# Node 'Node 2' of graph 9886 misses edges.
# Node 'Node 1' of graph 9887 misses edges.
# Node 'Node 2' of graph 9887 misses edges.
# Node 'Node 1' of graph 9888 misses edges.
# Node 'Node 2' of graph 9888 misses edges.
# Node 'Node 1' of graph 9889 misses edges.
# Node 'Node 2' of graph 9889 misses edges.
# Node 'Node 1' of graph 9890 misses edges.
# Node 'Node 2' of graph 9890 misses edges.
# Node 'Node 1' of graph 9891 misses edges.
# Node 'Node 2' of graph 9891 misses edges.
# Node 'Node 1' of graph 9892 misses edges.
# Node 'Node 2' of graph 9892 misses edges.
# Node 'Node 1' of graph 9893 misses edges.
# Node 'Node 2' of graph 9893 misses edges.
# Node 'Node 1' of graph 9894 misses edges.
# Node 'Node 2' of graph 9894 misses edges.
# Node 'Node 1' of graph 9895 misses edges.
# Node 'Node 2' of graph 9895 misses edges.
# Node 'Node 1' of graph 9896 misses edges.
# Node 'Node 2' of graph 9896 misses edges.
# Node 'Node 1' of graph 9897 misses edges.
# Node 'Node 2' of graph 9897 misses edges.
# Node 'Node 1' of graph 9898 misses edges.
# Node 'Node 2' of graph 9898 misses edges.
# Node 'Node 1' of graph 9899 misses edges.
# Node 'Node 2' of graph 9899 misses edges.
# Node 'Node 1' of graph 9900 misses edges.
# Node 'Node 2' of graph 9900 misses edges.
# Node 'Node 1' of graph 9901 misses edges.
# Node 'Node 2' of graph 9901 misses edges.
# Node 'Node 1' of graph 9902 misses edges.
# Node 'Node 2' of graph 9902 misses edges.
# Node 'Node 1' of graph 9903 misses edges.
# Node 'Node 2' of graph 9903 misses edges.
# Node 'Node 1' of graph 9904 misses edges.
# Node 'Node 2' of graph 9904 misses edges.
# Node 'Node 1' of graph 9905 misses edges.
# Node 'Node 2' of graph 9905 misses edges.
# Node 'Node 1' of graph 9906 misses edges.
# Node 'Node 2' of graph 9906 misses edges.
# Node 'Node 1' of graph 9907 misses edges.
# Node 'Node 2' of graph 9907 misses edges.
# Node 'Node 1' of graph 9908 misses edges.
# Node 'Node 2' of graph 9908 misses edges.
# Node 'Node 1' of graph 9909 misses edges.
# Node 'Node 2' of graph 9909 misses edges.
# Node 'Node 1' of graph 9910 misses edges.
# Node 'Node 2' of graph 9910 misses edges.
# Node 'Node 1' of graph 9911 misses edges.
# Node 'Node 2' of graph 9911 misses edges.
# Node 'Node 1' of graph 9912 misses edges.
# Node 'Node 2' of graph 9912 misses edges.
# Node 'Node 1' of graph 9913 misses edges.
# Node 'Node 2' of graph 9913 misses edges.
# Node 'Node 1' of graph 9914 misses edges.
# Node 'Node 2' of graph 9914 misses edges.
# Node 'Node 1' of graph 9915 misses edges.
# Node 'Node 2' of graph 9915 misses edges.
# Node 'Node 1' of graph 9916 misses edges.
# Node 'Node 2' of graph 9916 misses edges.
# Node 'Node 1' of graph 9917 misses edges.
# Node 'Node 2' of graph 9917 misses edges.
# Node 'Node 1' of graph 9918 misses edges.
# Node 'Node 2' of graph 9918 misses edges.
# Node 'Node 1' of graph 9919 misses edges.
# Node 'Node 2' of graph 9919 misses edges.
# Node 'Node 1' of graph 9920 misses edges.
# Node 'Node 2' of graph 9920 misses edges.
# Node 'Node 1' of graph 9921 misses edges.
# Node 'Node 2' of graph 9921 misses edges.
# Node 'Node 1' of graph 9922 misses edges.
# Node 'Node 2' of graph 9922 misses edges.
# Node 'Node 1' of graph 9923 misses edges.
# Node 'Node 2' of graph 9923 misses edges.
# Node 'Node 1' of graph 9924 misses edges.
# Node 'Node 2' of graph 9924 misses edges.
# Node 'Node 1' of graph 9925 misses edges.
# Node 'Node 2' of graph 9925 misses edges.
# Node 'Node 1' of graph 9926 misses edges.
# Node 'Node 2' of graph 9926 misses edges.
# Node 'Node 1' of graph 9927 misses edges.
# Node 'Node 2' of graph 9927 misses edges.
# Node 'Node 1' of graph 9928 misses edges.
# Node 'Node 2' of graph 9928 misses edges.
# Node 'Node 1' of graph 9929 misses edges.
# Node 'Node 2' of graph 9929 misses edges.
# Node 'Node 1' of graph 9930 misses edges.
# Node 'Node 2' of graph 9930 misses edges.
# Node 'Node 1' of graph 9931 misses edges.
# Node 'Node 2' of graph 9931 misses edges.
# Node 'Node 1' of graph 9932 misses edges.
# Node 'Node 2' of graph 9932 misses edges.
# Node 'Node 1' of graph 9933 misses edges.
# Node 'Node 2' of graph 9933 misses edges.
# Node 'Node 1' of graph 9934 misses edges.
# Node 'Node 2' of graph 9934 misses edges.
# Node 'Node 1' of graph 9935 misses edges.
# Node 'Node 2' of graph 9935 misses edges.
# Node 'Node 1' of graph 9936 misses edges.
# Node 'Node 2' of graph 9936 misses edges.
# Node 'Node 1' of graph 9937 misses edges.
# Node 'Node 2' of graph 9937 misses edges.
# Node 'Node 1' of graph 9938 misses edges.
# Node 'Node 2' of graph 9938 misses edges.
# Node 'Node 1' of graph 9939 misses edges.
# Node 'Node 2' of graph 9939 misses edges.
# Node 'Node 1' of graph 9940 misses edges.
# Node 'Node 2' of graph 9940 misses edges.
# Node 'Node 1' of graph 9941 misses edges.
# Node 'Node 2' of graph 9941 misses edges.
# Node 'Node 1' of graph 9942 misses edges.
# Node 'Node 2' of graph 9942 misses edges.
# Node 'Node 1' of graph 9943 misses edges.
# Node 'Node 2' of graph 9943 misses edges.
# Node 'Node 1' of graph 9944 misses edges.
# Node 'Node 2' of graph 9944 misses edges.
# Node 'Node 1' of graph 9945 misses edges.
# Node 'Node 2' of graph 9945 misses edges.
# Node 'Node 1' of graph 9946 misses edges.
# Node 'Node 2' of graph 9946 misses edges.
# Node 'Node 1' of graph 9947 misses edges.
# Node 'Node 2' of graph 9947 misses edges.
# Node 'Node 1' of graph 9948 misses edges.
# Node 'Node 2' of graph 9948 misses edges.
# Node 'Node 1' of graph 9949 misses edges.
# Node 'Node 2' of graph 9949 misses edges.
# Node 'Node 1' of graph 9950 misses edges.
# Node 'Node 2' of graph 9950 misses edges.
# Node 'Node 1' of graph 9951 misses edges.
# Node 'Node 2' of graph 9951 misses edges.
# Node 'Node 1' of graph 9952 misses edges.
# Node 'Node 2' of graph 9952 misses edges.
# Node 'Node 1' of graph 9953 misses edges.
# Node 'Node 2' of graph 9953 misses edges.
# Node 'Node 1' of graph 9954 misses edges.
# Node 'Node 2' of graph 9954 misses edges.
# Node 'Node 1' of graph 9955 misses edges.
# Node 'Node 2' of graph 9955 misses edges.
# Node 'Node 1' of graph 9956 misses edges.
# Node 'Node 2' of graph 9956 misses edges.
# Node 'Node 1' of graph 9957 misses edges.
# Node 'Node 2' of graph 9957 misses edges.
# Node 'Node 1' of graph 9958 misses edges.
# Node 'Node 2' of graph 9958 misses edges.
# Node 'Node 1' of graph 9959 misses edges.
# Node 'Node 2' of graph 9959 misses edges.
# Node 'Node 1' of graph 9960 misses edges.
# Node 'Node 2' of graph 9960 misses edges.
# Node 'Node 1' of graph 9961 misses edges.
# Node 'Node 2' of graph 9961 misses edges.
# Node 'Node 1' of graph 9962 misses edges.
# Node 'Node 2' of graph 9962 misses edges.
# Node 'Node 1' of graph 9963 misses edges.
# Node 'Node 2' of graph 9963 misses edges.
# Node 'Node 1' of graph 9964 misses edges.
# Node 'Node 2' of graph 9964 misses edges.
# Node 'Node 1' of graph 9965 misses edges.
# Node 'Node 2' of graph 9965 misses edges.
# Node 'Node 1' of graph 9966 misses edges.
# Node 'Node 2' of graph 9966 misses edges.
# Node 'Node 1' of graph 9967 misses edges.
# Node 'Node 2' of graph 9967 misses edges.
# Node 'Node 1' of graph 9968 misses edges.
# Node 'Node 2' of graph 9968 misses edges.
# Node 'Node 1' of graph 9969 misses edges.
# Node 'Node 2' of graph 9969 misses edges.
# Node 'Node 1' of graph 9970 misses edges.
# Node 'Node 2' of graph 9970 misses edges.
# Node 'Node 1' of graph 9971 misses edges.
# Node 'Node 2' of graph 9971 misses edges.
# Node 'Node 1' of graph 9972 misses edges.
# Node 'Node 2' of graph 9972 misses edges.
# Node 'Node 1' of graph 9973 misses edges.
# Node 'Node 2' of graph 9973 misses edges.
# Node 'Node 1' of graph 9974 misses edges.
# Node 'Node 2' of graph 9974 misses edges.
# Node 'Node 1' of graph 9975 misses edges.
# Node 'Node 2' of graph 9975 misses edges.
# Node 'Node 1' of graph 9976 misses edges.
# Node 'Node 2' of graph 9976 misses edges.
# Node 'Node 1' of graph 9977 misses edges.
# Node 'Node 2' of graph 9977 misses edges.
# Node 'Node 1' of graph 9978 misses edges.
# Node 'Node 2' of graph 9978 misses edges.
# Node 'Node 1' of graph 9979 misses edges.
# Node 'Node 2' of graph 9979 misses edges.
# Node 'Node 1' of graph 9980 misses edges.
# Node 'Node 2' of graph 9980 misses edges.
# Node 'Node 1' of graph 9981 misses edges.
# Node 'Node 2' of graph 9981 misses edges.
# Node 'Node 1' of graph 9982 misses edges.
# Node 'Node 2' of graph 9982 misses edges.
# Node 'Node 1' of graph 9983 misses edges.
# Node 'Node 2' of graph 9983 misses edges.
# Node 'Node 1' of graph 9984 misses edges.
# Node 'Node 2' of graph 9984 misses edges.
# Node 'Node 1' of graph 9985 misses edges.
# Node 'Node 2' of graph 9985 misses edges.
# Node 'Node 1' of graph 9986 misses edges.
# Node 'Node 2' of graph 9986 misses edges.
# Node 'Node 1' of graph 9987 misses edges.
# Node 'Node 2' of graph 9987 misses edges.
# Node 'Node 1' of graph 9988 misses edges.
# Node 'Node 2' of graph 9988 misses edges.
# Node 'Node 1' of graph 9989 misses edges.
# Node 'Node 2' of graph 9989 misses edges.
# Node 'Node 1' of graph 9990 misses edges.
# Node 'Node 2' of graph 9990 misses edges.
# Node 'Node 1' of graph 9991 misses edges.
# Node 'Node 2' of graph 9991 misses edges.
# Node 'Node 1' of graph 9992 misses edges.
# Node 'Node 2' of graph 9992 misses edges.
# Node 'Node 1' of graph 9993 misses edges.
# Node 'Node 2' of graph 9993 misses edges.
# Node 'Node 1' of graph 9994 misses edges.
# Node 'Node 2' of graph 9994 misses edges.
# Node 'Node 1' of graph 9995 misses edges.
# Node 'Node 2' of graph 9995 misses edges.
# Node 'Node 1' of graph 9996 misses edges.
# Node 'Node 2' of graph 9996 misses edges.
# Node 'Node 1' of graph 9997 misses edges.
# Node 'Node 2' of graph 9997 misses edges.
# Node 'Node 1' of graph 9998 misses edges.
# Node 'Node 2' of graph 9998 misses edges.
# Node 'Node 1' of graph 9999 misses edges.
# Node 'Node 2' of graph 9999 misses edges.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: -1
# /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
graphs_test = Graphs(args.number_of_examples, init_with=graphs_train)

for graph_id in range(args.number_of_examples):
    graphs_test.set_number_of_graph_nodes(graph_id, 2)

graphs_test.prepare_node_configuration()

for graph_id in range(args.number_of_examples):
    number_of_outgoing_edges = 1
    graphs_test.add_graph_node(graph_id, 'Node 1', number_of_outgoing_edges)
    graphs_test.add_graph_node(graph_id, 'Node 2', number_of_outgoing_edges)

graphs_test.prepare_edge_configuration()

for graph_id in range(args.number_of_examples):
    edge_type = "Plain"
    graphs_test.add_graph_node_edge(graph_id, 'Node 1', 'Node 2', edge_type)
    graphs_test.add_graph_node_edge(graph_id, 'Node 2', 'Node 1', edge_type)

Y_test = np.empty(args.number_of_examples, dtype=np.uint32)
for graph_id in range(args.number_of_examples):
    x1 = random.choice(['A', 'B'])
    x2 = random.choice(['A', 'B'])

    graphs_test.add_graph_node_property(graph_id, 'Node 1', x1)
    graphs_test.add_graph_node_property(graph_id, 'Node 2', x2)

    if x1 == x2:
        Y_test[graph_id] = 0
    else:
        Y_test[graph_id] = 1

graphs_test.encode()

tm = MultiClassGraphTsetlinMachine(
    args.number_of_clauses,
    args.T,
    args.s,
    depth = args.depth,
    message_size = args.message_size,
    message_bits = args.message_bits,
    max_included_literals = args.max_included_literals
)

for i in range(args.epochs):
    start_training = time()
    tm.fit(graphs_train, Y_train, epochs=1, incremental=True)
    stop_training = time()

    start_testing = time()
    result_test = 100*(tm.predict(graphs_test) == Y_test).mean()
    stop_testing = time()

    result_train = 100*(tm.predict(graphs_train) == Y_train).mean()

    print("%d %.2f %.2f %.2f %.2f" % (i, result_train, result_test, stop_training-start_training, stop_testing-start_testing))

weights = tm.get_state()[1].reshape(2, -1)
for i in range(tm.number_of_clauses):
        print("Clause #%d W:(%d %d)" % (i, weights[0,i], weights[1,i]), end=' ')
        l = []
        for k in range(args.hypervector_size * 2):
            if tm.ta_action(0, i, k):
                if k < args.hypervector_size:
                    l.append("x%d" % (k))
                else:
                    l.append("NOT x%d" % (k - args.hypervector_size))

        # for k in range(args.message_size * 2):
        #     if tm.ta_action(1, i, k):
        #         if k < args.message_size:
        #             l.append("c%d" % (k))
        #         else:
        #             l.append("NOT c%d" % (k - args.message_size))

        print(" AND ".join(l))

print(graphs_test.hypervectors)
print(tm.hypervectors)
print(graphs_test.edge_type_id)
