# %%
from GraphTsetlinMachine.graphs import Graphs
import numpy as np
from scipy.sparse import csr_matrix
from GraphTsetlinMachine.tm import MultiClassGraphTsetlinMachine
from time import time
import argparse
import random
import csv

# %%
def default_args(**kwargs):
    parser = argparse.ArgumentParser()
    parser.add_argument("--epochs", default=25, type=int)
    parser.add_argument("--number-of-clauses", default=10000, type=int)
    parser.add_argument("--T", default=np.power((1000/0.8377),1/2.2099), type=int)
    parser.add_argument("--s", default=2.534*np.log((1000/3.7579)), type=float)
    parser.add_argument("--depth", default=5, type=int)
    parser.add_argument("--hypervector-size", default=32, type=int)
    parser.add_argument("--hypervector-bits", default=2, type=int)
    parser.add_argument("--message-size", default=256, type=int)
    parser.add_argument("--message-bits", default=2, type=int)
    parser.add_argument('--double-hashing', dest='double_hashing', default=False, action='store_true')
    parser.add_argument("--noise", default=0.01, type=float)
    parser.add_argument("--number-of-examples", default=10000, type=int)
    parser.add_argument("--max-included-literals", default=32, type=int)

    args, unknown = parser.parse_known_args()
    for key, value in kwargs.items():
        if key in args.__dict__:
            setattr(args, key, value)
    return args

args = default_args()

# %%
print("Loading data")
input_file = 'hex_games_1_000_000_size_7.csv'

# Read the entire CSV file into a list of rows
with open(input_file, mode='r', newline='') as infile:
    reader = csv.reader(infile)
    data = list(reader)


delete_index = int(0.98 * len(data))
data = data[delete_index:]
# Split the data into training (80%) and testing (20%) sets
split_index = int(0.8 * len(data))
train_data = data[:split_index]
test_data = data[split_index:]

# Separate X_data and Y_data for training set
X_train = np.array([row[:-1] for row in train_data], dtype=int)
Y_train = np.array([row[-1:] for row in train_data], dtype=int)

# Separate X_data and Y_data for testing set
X_test = np.array([row[:-1] for row in test_data], dtype=int)
Y_test = np.array([row[-1:] for row in test_data], dtype=int)

X_train = X_train.reshape(-1, 7, 7)
X_test = X_test.reshape(-1, 7, 7)

Y_train = Y_train.reshape(-1)
Y_test = Y_test.reshape(-1)

Y_train = np.where(Y_train == -1, 0, Y_train)
Y_test = np.where(Y_test == -1, 0, Y_test)


# Print the shapes of the arrays
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)
print("X_test shape:", X_test.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# Loading data
# X_train shape: (16000, 7, 7)
# Y_train shape: (16000,)
# X_test shape: (4000, 7, 7)
# Y_test shape: (4000,)

# %%
print("Creating training data")

# Create train data

graphs_train = Graphs(
    X_train.shape[0],
    symbols=['A', 'B', 'O'],
    hypervector_size=args.hypervector_size,
    hypervector_bits=args.hypervector_bits,
)

patch_size = 1
dim = 7 - patch_size + 1

number_of_nodes = dim * dim

print(patch_size, dim, number_of_nodes)

for graph_id in range(X_train.shape[0]):
    graphs_train.set_number_of_graph_nodes(graph_id, number_of_nodes)
    
graphs_train.prepare_node_configuration()
print("Finished preparing node configuration")

map_size = 7 # 7 x 7
data_size = 10000
directions = [
    (-1, 0), (1, 0),  # Left and Right
    (0, -1), (0, 1),  # Up and Down
    (-1, 1), (1, -1)  # Upper-left and Lower-right for staggered rows
]

for graph_id in range(X_train.shape[0]):
    for x in range(map_size):
        for y in range(map_size):
            node_id = x * map_size + y
            number_of_outgoing_edges = 0
            
            for dx, dy in directions:
                neighbor_x = x + dx
                neighbor_y = y + dy
                
                # Check if neighbor exists within bounds
                if 0 <= neighbor_x < map_size and 0 <= neighbor_y < map_size:
                    number_of_outgoing_edges += 1
            # Use the node_counter to create a unique label for each node
            graphs_train.add_graph_node(graph_id, node_id, number_of_outgoing_edges)
            
    
print("All nodes are acounted for")
graphs_train.prepare_edge_configuration()
edge_type = "Plain"

for graph_id in range(X_train.shape[0]):
    for x in range(map_size):
        for y in range(map_size):
            node_id = x * map_size + y
            number_of_outgoing_edges = 0
            
            for dx, dy in directions:
                neighbor_x = x + dx
                neighbor_y = y + dy

                # Check if neighbor exists within bounds
                if 0 <= neighbor_x < map_size and 0 <= neighbor_y < map_size:
                    neighbor_id = neighbor_x * map_size + neighbor_y
                    graphs_train.add_graph_node_edge(graph_id, node_id, neighbor_id, edge_type)
print("Added neighbor edges")
# Out:
# Creating training data
# 1 7 49
# Finished preparing node configuration
# All nodes are acounted for
# Added neighbor edges

# %%
print("Preparing to add briks to the board")
for graph_id in range(X_train.shape[0]):
    for x in range(map_size):
        for y in range(map_size):
            node_id = x * map_size + y
            
            if X_train[graph_id][y][x] == -1:
                brick = 'A'
            elif X_train[graph_id][y][x] == 1:
                brick = 'B'
            else:
                brick = 'O'
            graphs_train.add_graph_node_property(graph_id, node_id, brick)

graphs_train.encode()
print("All cells has now a brick")
# Out:
# Preparing to add briks to the board
# All cells has now a brick

# %%
print("Creating training data")

# Create train data

graphs_test = Graphs(
    X_test.shape[0],
    symbols=['A', 'B', 'O'],
    hypervector_size=args.hypervector_size,
    hypervector_bits=args.hypervector_bits,
)

patch_size = 1
dim = 7 - patch_size + 1

number_of_nodes = dim * dim

print(patch_size, dim, number_of_nodes)

for graph_id in range(X_test.shape[0]):
    graphs_test.set_number_of_graph_nodes(graph_id, number_of_nodes)
    
graphs_test.prepare_node_configuration()
print("Finished preparing node configuration")

map_size = 7 # 7 x 7
data_size = 10000
directions = [
    (-1, 0), (1, 0),  # Left and Right
    (0, -1), (0, 1),  # Up and Down
    (-1, 1), (1, -1)  # Upper-left and Lower-right for staggered rows
]

for graph_id in range(X_test.shape[0]):
    for x in range(map_size):
        for y in range(map_size):
            node_id = x * map_size + y
            number_of_outgoing_edges = 0
            
            for dx, dy in directions:
                neighbor_x = x + dx
                neighbor_y = y + dy
                
                # Check if neighbor exists within bounds
                if 0 <= neighbor_x < map_size and 0 <= neighbor_y < map_size:
                    number_of_outgoing_edges += 1

            # Use the node_counter to create a unique label for each node
            graphs_test.add_graph_node(graph_id, node_id, number_of_outgoing_edges)
            


print("All nodes are acounted for")
graphs_test.prepare_edge_configuration()
edge_type = "Plain"


for graph_id in range(X_test.shape[0]):
    for x in range(map_size):
        for y in range(map_size):
            node_id = x * map_size + y
            number_of_outgoing_edges = 0
    
            
            for dx, dy in directions:
                neighbor_x = x + dx
                neighbor_y = y + dy

                # Check if neighbor exists within bounds
                if 0 <= neighbor_x < map_size and 0 <= neighbor_y < map_size:
                    neighbor_id = neighbor_x * map_size + neighbor_y
                    graphs_test.add_graph_node_edge(graph_id, node_id, neighbor_id, edge_type)
print("Added neighbor edges")
# Out:
# Creating training data
# 1 7 49
# Finished preparing node configuration
# All nodes are acounted for
# Added neighbor edges

# %%
print("Preparing to add briks to the board")
for graph_id in range(X_test.shape[0]):
    for x in range(map_size):
        for y in range(map_size):
            node_id = x * map_size + y
            
            if X_test[graph_id][y][x] == -1:
                brick = 'A'
            elif X_test[graph_id][y][x] == 1:
                brick = 'B'
            else:
                brick = 'O'
            graphs_test.add_graph_node_property(graph_id, node_id, brick)

graphs_test.encode()
print("All cells has now a brick")
# Out:
# Preparing to add briks to the board
# All cells has now a brick

# %%
tm = MultiClassGraphTsetlinMachine(
    args.number_of_clauses,
    args.T,
    args.s,
    depth = args.depth,
    message_size = args.message_size,
    message_bits = args.message_bits,
    max_included_literals = args.max_included_literals
)

for i in range(args.epochs):
    start_training = time()
    tm.fit(graphs_train, Y_train, epochs=1, incremental=True)
    stop_training = time()

    start_testing = time()
    #print(tm.predict(graphs_test))
    result_test = 100*(tm.predict(graphs_test) == Y_test).mean()
    #print(tm.predict(graphs_test))
    stop_testing = time()

    result_train = 100*(tm.predict(graphs_train) == Y_train).mean()

    print("%d %.2f %.2f %.2f %.2f" % (i, result_train, result_test, stop_training-start_training, stop_testing-start_testing))

weights = tm.get_state()[1].reshape(2, -1)
for i in range(tm.number_of_clauses):
        print("Clause #%d W:(%d %d)" % (i, weights[0,i], weights[1,i]), end=' ')
        l = []
        for k in range(args.hypervector_size * 2):
            if tm.ta_action(0, i, k):
                if k < args.hypervector_size:
                    l.append("x%d" % (k))
                else:
                    l.append("NOT x%d" % (k - args.hypervector_size))

        # for k in range(args.message_size * 2):
        #     if tm.ta_action(1, i, k):
        #         if k < args.message_size:
        #             l.append("c%d" % (k))
        #         else:
        #             l.append("NOT c%d" % (k - args.message_size))

        print(" AND ".join(l))

print(graphs_test.hypervectors)
print(tm.hypervectors)
print(graphs_test.edge_type_id)
# Out:
# Initialization of sparse structure.
# 0 53.99 53.95 15.92 2.02
# 1 53.99 53.95 14.24 2.02
# 2 53.99 53.95 14.21 2.03
# 3 53.99 53.95 14.20 2.01
# 4 53.99 53.95 14.20 2.04
# 5 53.99 53.95 14.20 1.99
# 6 53.99 53.95 14.22 2.05
# 7 53.99 53.95 14.22 2.04
# 8 53.99 53.95 14.24 2.06
# 9 53.99 53.95 14.23 1.99
# 10 53.99 53.95 14.25 2.05
# 11 53.99 53.95 14.22 2.01
# 12 53.99 53.95 14.20 2.01
# 13 53.99 53.95 14.42 2.01
# 14 53.99 53.95 92.60 18.07
# 15 53.99 53.95 98.24 16.69
# 16 53.99 53.95 94.52 17.77
# 17 53.99 53.95 98.28 15.28
# 18 53.99 53.95 14.13 2.00
# 19 53.99 53.95 14.20 1.99
# 20 53.99 53.95 14.18 2.02
# 21 53.99 53.95 14.20 2.03
# 22 53.99 53.95 14.20 2.00
# 23 53.99 53.95 14.20 2.00
# 24 53.99 53.95 14.20 2.01
# Clause #0 W:(0 -3)
# Clause #1 W:(0 1)
# Clause #2 W:(1 1)
# Clause #3 W:(-1 0)
# Clause #4 W:(0 -2)
# Clause #5 W:(-1 1)
# Clause #6 W:(-1 -4)
# Clause #7 W:(0 2)
# Clause #8 W:(0 0)
# Clause #9 W:(0 1)
# Clause #10 W:(2 0)
# Clause #11 W:(1 -2)
# Clause #12 W:(-1 -1)
# Clause #13 W:(0 1)
# Clause #14 W:(0 -2)
# Clause #15 W:(1 -1)
# Clause #16 W:(0 1)
# Clause #17 W:(1 -1)
# Clause #18 W:(1 1)
# Clause #19 W:(-1 0)
# Clause #20 W:(-1 -3)
# Clause #21 W:(0 0)
# Clause #22 W:(0 -2)
# Clause #23 W:(0 1)
# Clause #24 W:(-1 -1)
# Clause #25 W:(0 -1)
# Clause #26 W:(0 1)
# Clause #27 W:(0 -2)
# Clause #28 W:(0 0)
# Clause #29 W:(0 -1)
# Clause #30 W:(-1 -1)
# Clause #31 W:(0 0)
# Clause #32 W:(0 1)
# Clause #33 W:(0 -1)
# Clause #34 W:(0 0)
# Clause #35 W:(0 0)
# Clause #36 W:(0 1)
# Clause #37 W:(0 -1) x26
# Clause #38 W:(-3 -1)
# Clause #39 W:(3 0)
# Clause #40 W:(-2 0)
# Clause #41 W:(2 3)
# Clause #42 W:(3 0)
# Clause #43 W:(0 1)
# Clause #44 W:(-1 -1)
# Clause #45 W:(-1 1)
# Clause #46 W:(-1 -1)
# Clause #47 W:(0 2)
# Clause #48 W:(-1 1)
# Clause #49 W:(1 1)
# Clause #50 W:(-1 -1)
# Clause #51 W:(0 -3)
# Clause #52 W:(1 1)
# Clause #53 W:(0 -1)
# Clause #54 W:(0 0)
# Clause #55 W:(-1 1)
# Clause #56 W:(0 -1)
# Clause #57 W:(0 2)
# Clause #58 W:(-1 7) x22
# Clause #59 W:(-1 -3)
# Clause #60 W:(-1 0)
# Clause #61 W:(0 1)
# Clause #62 W:(0 3)
# Clause #63 W:(-1 2)
# Clause #64 W:(0 0)
# Clause #65 W:(0 -2)
# Clause #66 W:(0 0)
# Clause #67 W:(0 0)
# Clause #68 W:(0 -1)
# Clause #69 W:(0 0)
# Clause #70 W:(1 1)
# Clause #71 W:(-1 0)
# Clause #72 W:(0 3)
# Clause #73 W:(-4 -1)
# Clause #74 W:(-1 -2)
# Clause #75 W:(-1 1)
# Clause #76 W:(0 3)
# Clause #77 W:(0 -1)
# Clause #78 W:(-3 -2)
# Clause #79 W:(0 -2)
# Clause #80 W:(-1 -2)
# Clause #81 W:(-4 -6)
# Clause #82 W:(1 -1)
# Clause #83 W:(0 -3)
# Clause #84 W:(2 3)
# Clause #85 W:(-1 -2)
# Clause #86 W:(-1 -1)
# Clause #87 W:(0 -2)
# Clause #88 W:(2 0)
# Clause #89 W:(-2 -2)
# Clause #90 W:(0 0)
# Clause #91 W:(-2 -1)
# Clause #92 W:(0 -1)
# Clause #93 W:(0 -1)
# Clause #94 W:(-1 0)
# Clause #95 W:(0 -2)
# Clause #96 W:(-1 -1)
# Clause #97 W:(-1 -3)
# Clause #98 W:(0 1)
# Clause #99 W:(-1 1)
# Clause #100 W:(2 0)
# Clause #101 W:(0 3)
# Clause #102 W:(-1 1)
# Clause #103 W:(2 -1)
# Clause #104 W:(0 0)
# Clause #105 W:(-3 0)
# Clause #106 W:(-1 -1)
# Clause #107 W:(-1 -3) x3
# Clause #108 W:(-1 -2)
# Clause #109 W:(1 0)
# Clause #110 W:(-4 -1)
# Clause #111 W:(1 -1)
# Clause #112 W:(0 1)
# Clause #113 W:(0 0)
# Clause #114 W:(1 2)
# Clause #115 W:(5 -1) x25
# Clause #116 W:(2 0)
# Clause #117 W:(-3 -2)
# Clause #118 W:(3 3)
# Clause #119 W:(0 1) x14
# Clause #120 W:(1 -1)
# Clause #121 W:(-1 3)
# Clause #122 W:(0 4)
# Clause #123 W:(-1 0)
# Clause #124 W:(3 -1)
# Clause #125 W:(1 0)
# Clause #126 W:(1 -1)
# Clause #127 W:(-3 -3)
# Clause #128 W:(-1 -1) x11
# Clause #129 W:(0 0)
# Clause #130 W:(0 0)
# Clause #131 W:(1 1)
# Clause #132 W:(-1 -2)
# Clause #133 W:(-3 0)
# Clause #134 W:(8 -1)
# Clause #135 W:(1 0)
# Clause #136 W:(2 -1)
# Clause #137 W:(0 0)
# Clause #138 W:(0 1)
# Clause #139 W:(-3 -1)
# Clause #140 W:(-4 -2) x15 AND x19
# Clause #141 W:(-1 -1)
# Clause #142 W:(-1 -2)
# Clause #143 W:(-1 -1)
# Clause #144 W:(0 -1) x5
# Clause #145 W:(-1 0)
# Clause #146 W:(0 -2)
# Clause #147 W:(0 -1)
# Clause #148 W:(-3 -1)
# Clause #149 W:(-1 -1)
# Clause #150 W:(-2 -1)
# Clause #151 W:(-1 0)
# Clause #152 W:(-1 0)
# Clause #153 W:(-2 -1)
# Clause #154 W:(0 0)
# Clause #155 W:(-1 2)
# Clause #156 W:(1 4)
# Clause #157 W:(0 -1)
# Clause #158 W:(-1 -1)
# Clause #159 W:(-1 2)
# Clause #160 W:(-2 -1)
# Clause #161 W:(0 -2)
# Clause #162 W:(-1 2)
# Clause #163 W:(0 -2)
# Clause #164 W:(-1 -2)
# Clause #165 W:(-1 -4)
# Clause #166 W:(-1 0)
# Clause #167 W:(0 0)
# Clause #168 W:(0 0)
# Clause #169 W:(-1 0)
# Clause #170 W:(0 0) x3
# Clause #171 W:(-1 0) x23
# Clause #172 W:(2 2)
# Clause #173 W:(0 -1)
# Clause #174 W:(-1 2)
# Clause #175 W:(-2 0)
# Clause #176 W:(0 1)
# Clause #177 W:(2 -1)
# Clause #178 W:(2 -1)
# Clause #179 W:(-1 -1)
# Clause #180 W:(0 -1) x27
# Clause #181 W:(-1 -1)
# Clause #182 W:(-1 0)
# Clause #183 W:(0 -1)
# Clause #184 W:(0 1)
# Clause #185 W:(-1 0)
# Clause #186 W:(2 0)
# Clause #187 W:(0 5)
# Clause #188 W:(1 0)
# Clause #189 W:(4 0) x6
# Clause #190 W:(-3 0)
# Clause #191 W:(3 5)
# Clause #192 W:(-1 0) x5
# Clause #193 W:(-1 -1)
# Clause #194 W:(0 -1)
# Clause #195 W:(0 1)
# Clause #196 W:(-2 -1)
# Clause #197 W:(0 2)
# Clause #198 W:(-1 -2)
# Clause #199 W:(0 -1)
# Clause #200 W:(1 1)
# Clause #201 W:(-1 1)
# Clause #202 W:(1 1)
# Clause #203 W:(-1 0)
# Clause #204 W:(-1 0) x23
# Clause #205 W:(4 3)
# Clause #206 W:(0 -1) x14
# Clause #207 W:(-1 -1)
# Clause #208 W:(-2 -1)
# Clause #209 W:(1 1)
# Clause #210 W:(0 0)
# Clause #211 W:(-1 0)
# Clause #212 W:(-1 0)
# Clause #213 W:(0 -1)
# Clause #214 W:(-1 1)
# Clause #215 W:(0 -1)
# Clause #216 W:(-1 1)
# Clause #217 W:(-1 1)
# Clause #218 W:(1 -1)
# Clause #219 W:(-1 -1)
# Clause #220 W:(-1 3)
# Clause #221 W:(0 1)
# Clause #222 W:(-1 0)
# Clause #223 W:(1 2)
# Clause #224 W:(0 0)
# Clause #225 W:(-2 -1)
# Clause #226 W:(-1 0)
# Clause #227 W:(2 0)
# Clause #228 W:(-1 -4)
# Clause #229 W:(0 -3)
# Clause #230 W:(1 0)
# Clause #231 W:(0 -3)
# Clause #232 W:(2 0)
# Clause #233 W:(0 2)
# Clause #234 W:(-1 4)
# Clause #235 W:(2 -1)
# Clause #236 W:(1 0) x6
# Clause #237 W:(1 1) x7
# Clause #238 W:(1 1)
# Clause #239 W:(-2 -2)
# Clause #240 W:(1 1) x17
# Clause #241 W:(2 -1)
# Clause #242 W:(0 0)
# Clause #243 W:(-1 -2) x8
# Clause #244 W:(-2 -3)
# Clause #245 W:(1 0)
# Clause #246 W:(-1 0)
# Clause #247 W:(1 -1)
# Clause #248 W:(-1 0) x4
# Clause #249 W:(-1 3)
# Clause #250 W:(0 -1)
# Clause #251 W:(-1 1)
# Clause #252 W:(0 0) x18 AND x20
# Clause #253 W:(0 -1) x4 AND x26
# Clause #254 W:(-1 -1)
# Clause #255 W:(0 0)
# Clause #256 W:(-1 -3)
# Clause #257 W:(2 -1)
# Clause #258 W:(-1 2)
# Clause #259 W:(0 0)
# Clause #260 W:(-1 2)
# Clause #261 W:(0 3)
# Clause #262 W:(1 0)
# Clause #263 W:(2 1)
# Clause #264 W:(-2 -3)
# Clause #265 W:(-1 1)
# Clause #266 W:(0 0)
# Clause #267 W:(-1 -1)
# Clause #268 W:(1 1)
# Clause #269 W:(1 0) x18
# Clause #270 W:(1 1)
# Clause #271 W:(0 -1) x28
# Clause #272 W:(-2 0)
# Clause #273 W:(1 0) x27
# Clause #274 W:(-1 1)
# Clause #275 W:(0 0)
# Clause #276 W:(0 0)
# Clause #277 W:(-1 1)
# Clause #278 W:(-2 -1)
# Clause #279 W:(0 2)
# Clause #280 W:(-1 -1) x14
# Clause #281 W:(0 -1)
# Clause #282 W:(3 -1)
# Clause #283 W:(4 1)
# Clause #284 W:(0 1)
# Clause #285 W:(4 -1)
# Clause #286 W:(-1 -2)
# Clause #287 W:(-1 -3)
# Clause #288 W:(1 2)
# Clause #289 W:(1 0)
# Clause #290 W:(1 -1)
# Clause #291 W:(0 0)
# Clause #292 W:(-1 1)
# Clause #293 W:(1 0)
# Clause #294 W:(4 -1)
# Clause #295 W:(1 1)
# Clause #296 W:(-1 -2)
# Clause #297 W:(1 0)
# Clause #298 W:(0 2)
# Clause #299 W:(0 -1) x24
# Clause #300 W:(-3 0) x11
# Clause #301 W:(0 0)
# Clause #302 W:(-1 1)
# Clause #303 W:(1 1)
# Clause #304 W:(0 -1)
# Clause #305 W:(0 0)
# Clause #306 W:(2 2)
# Clause #307 W:(0 -1)
# Clause #308 W:(-2 -1)
# Clause #309 W:(-1 2) x8
# Clause #310 W:(0 0)
# Clause #311 W:(-1 -1)
# Clause #312 W:(0 0)
# Clause #313 W:(-1 2)
# Clause #314 W:(1 1)
# Clause #315 W:(1 -1)
# Clause #316 W:(-5 0)
# Clause #317 W:(4 2)
# Clause #318 W:(-1 2)
# Clause #319 W:(0 -1)
# Clause #320 W:(0 -1)
# Clause #321 W:(1 3)
# Clause #322 W:(0 1)
# Clause #323 W:(-1 -1)
# Clause #324 W:(-3 0) x14
# Clause #325 W:(-1 0)
# Clause #326 W:(-3 0) x11
# Clause #327 W:(-1 -1) x5
# Clause #328 W:(-1 0)
# Clause #329 W:(0 0)
# Clause #330 W:(0 1)
# Clause #331 W:(-2 0)
# Clause #332 W:(-2 0) x27
# Clause #333 W:(2 1)
# Clause #334 W:(2 0)
# Clause #335 W:(4 0)
# Clause #336 W:(-2 0)
# Clause #337 W:(-1 1)
# Clause #338 W:(1 -1)
# Clause #339 W:(-1 -1) x20
# Clause #340 W:(1 -1)
# Clause #341 W:(-1 0)
# Clause #342 W:(0 2)
# Clause #343 W:(1 2)
# Clause #344 W:(1 0)
# Clause #345 W:(0 2)
# Clause #346 W:(-1 3)
# Clause #347 W:(-1 1)
# Clause #348 W:(0 -2)
# Clause #349 W:(-2 -2)
# Clause #350 W:(-1 1) x11
# Clause #351 W:(3 0)
# Clause #352 W:(0 1)
# Clause #353 W:(-3 -1)
# Clause #354 W:(-1 -7)
# Clause #355 W:(-1 -1) x26
# Clause #356 W:(-1 -1) x24
# Clause #357 W:(1 0)
# Clause #358 W:(1 0)
# Clause #359 W:(0 0)
# Clause #360 W:(-1 0)
# Clause #361 W:(0 1)
# Clause #362 W:(0 0)
# Clause #363 W:(1 2) x12
# Clause #364 W:(2 1)
# Clause #365 W:(-1 -1) x22
# Clause #366 W:(1 1) x19
# Clause #367 W:(1 1) x11
# Clause #368 W:(1 -1) x19
# Clause #369 W:(0 0)
# Clause #370 W:(-1 -1)
# Clause #371 W:(0 2) x14
# Clause #372 W:(-1 -1)
# Clause #373 W:(-2 -1)
# Clause #374 W:(2 -1)
# Clause #375 W:(0 4)
# Clause #376 W:(-3 -1)
# Clause #377 W:(0 -1)
# Clause #378 W:(1 1)
# Clause #379 W:(-1 3)
# Clause #380 W:(-1 1)
# Clause #381 W:(1 3)
# Clause #382 W:(0 1)
# Clause #383 W:(-1 0)
# Clause #384 W:(1 0)
# Clause #385 W:(-1 0)
# Clause #386 W:(-1 0)
# Clause #387 W:(-1 1) x24
# Clause #388 W:(0 -2) x7
# Clause #389 W:(2 -1)
# Clause #390 W:(0 -1)
# Clause #391 W:(-1 -1)
# Clause #392 W:(0 -1)
# Clause #393 W:(-1 -1)
# Clause #394 W:(-2 -1)
# Clause #395 W:(-1 -1)
# Clause #396 W:(0 -1)
# Clause #397 W:(-3 0)
# Clause #398 W:(-1 0)
# Clause #399 W:(1 0)
# Clause #400 W:(-1 -1)
# Clause #401 W:(-2 -1)
# Clause #402 W:(0 -2)
# Clause #403 W:(-1 0)
# Clause #404 W:(0 -2)
# Clause #405 W:(3 -1)
# Clause #406 W:(1 -1)
# Clause #407 W:(0 0)
# Clause #408 W:(0 0)
# Clause #409 W:(1 -1)
# Clause #410 W:(-2 -1)
# Clause #411 W:(0 -1) x17
# Clause #412 W:(0 0)
# Clause #413 W:(0 0)
# Clause #414 W:(4 0) x7
# Clause #415 W:(0 -1)
# Clause #416 W:(1 -1)
# Clause #417 W:(1 1)
# Clause #418 W:(-1 1)
# Clause #419 W:(1 -1)
# Clause #420 W:(1 0)
# Clause #421 W:(-1 1)
# Clause #422 W:(-1 -1)
# Clause #423 W:(0 0)
# Clause #424 W:(1 0)
# Clause #425 W:(-1 -1)
# Clause #426 W:(-1 1)
# Clause #427 W:(-1 0) x10
# Clause #428 W:(0 -2)
# Clause #429 W:(-1 -3) x6
# Clause #430 W:(-1 -1)
# Clause #431 W:(-1 -1)
# Clause #432 W:(-1 -1) x23
# Clause #433 W:(-1 -1)
# Clause #434 W:(-3 -2)
# Clause #435 W:(2 0)
# Clause #436 W:(0 -4)
# Clause #437 W:(1 -1)
# Clause #438 W:(2 -1)
# Clause #439 W:(0 2) x4
# Clause #440 W:(0 -1)
# Clause #441 W:(1 1)
# Clause #442 W:(0 4)
# Clause #443 W:(-1 0)
# Clause #444 W:(2 0)
# Clause #445 W:(-1 3)
# Clause #446 W:(-2 0)
# Clause #447 W:(6 0)
# Clause #448 W:(1 -1)
# Clause #449 W:(-2 -1)
# Clause #450 W:(0 -3)
# Clause #451 W:(-1 2)
# Clause #452 W:(-1 -1)
# Clause #453 W:(-1 0)
# Clause #454 W:(0 0)
# Clause #455 W:(-1 0)
# Clause #456 W:(3 -1)
# Clause #457 W:(0 2)
# Clause #458 W:(0 -1)
# Clause #459 W:(-1 -1)
# Clause #460 W:(0 0)
# Clause #461 W:(2 1) x22
# Clause #462 W:(0 1) x23
# Clause #463 W:(2 1)
# Clause #464 W:(-1 -1) x4
# Clause #465 W:(-2 -2)
# Clause #466 W:(-1 -2)
# Clause #467 W:(0 -1)
# Clause #468 W:(0 -1)
# Clause #469 W:(-1 1)
# Clause #470 W:(-1 -2)
# Clause #471 W:(2 1)
# Clause #472 W:(-2 -1)
# Clause #473 W:(1 -1)
# Clause #474 W:(1 5)
# Clause #475 W:(-2 -1)
# Clause #476 W:(0 -1)
# Clause #477 W:(-1 0)
# Clause #478 W:(0 2)
# Clause #479 W:(-1 -1) x15
# Clause #480 W:(1 -1)
# Clause #481 W:(0 -1)
# Clause #482 W:(-1 -1)
# Clause #483 W:(0 -3)
# Clause #484 W:(0 0)
# Clause #485 W:(1 -1)
# Clause #486 W:(2 -1)
# Clause #487 W:(0 -1)
# Clause #488 W:(0 2)
# Clause #489 W:(2 0)
# Clause #490 W:(0 0)
# Clause #491 W:(0 0)
# Clause #492 W:(-1 0)
# Clause #493 W:(-1 0)
# Clause #494 W:(0 -1)
# Clause #495 W:(-2 -1)
# Clause #496 W:(-1 -3)
# Clause #497 W:(-1 -1)
# Clause #498 W:(0 0)
# Clause #499 W:(1 0)
# Clause #500 W:(0 0)
# Clause #501 W:(-1 1) x17
# Clause #502 W:(-2 0)
# Clause #503 W:(1 -1)
# Clause #504 W:(-1 -2)
# Clause #505 W:(-2 -1)
# Clause #506 W:(2 -1)
# Clause #507 W:(0 2)
# Clause #508 W:(0 0)
# Clause #509 W:(0 -1) x2
# Clause #510 W:(-1 -1) x27
# Clause #511 W:(0 5)
# Clause #512 W:(2 -1)
# Clause #513 W:(2 2)
# Clause #514 W:(0 -2)
# Clause #515 W:(0 -2)
# Clause #516 W:(0 0)
# Clause #517 W:(1 1)
# Clause #518 W:(-1 0)
# Clause #519 W:(1 0) x10
# Clause #520 W:(1 -1)
# Clause #521 W:(1 -1)
# Clause #522 W:(0 -3)
# Clause #523 W:(0 -5)
# Clause #524 W:(1 5)
# Clause #525 W:(-1 5)
# Clause #526 W:(-1 -2) x7
# Clause #527 W:(-1 2)
# Clause #528 W:(0 0)
# Clause #529 W:(-1 -1)
# Clause #530 W:(-1 1)
# Clause #531 W:(0 0)
# Clause #532 W:(2 -1)
# Clause #533 W:(1 -1)
# Clause #534 W:(1 1)
# Clause #535 W:(-1 0)
# Clause #536 W:(0 -2)
# Clause #537 W:(-2 0)
# Clause #538 W:(0 0)
# Clause #539 W:(-1 -1)
# Clause #540 W:(0 2) x18
# Clause #541 W:(2 1)
# Clause #542 W:(0 4)
# Clause #543 W:(0 0) x12
# Clause #544 W:(-1 1) x24
# Clause #545 W:(2 0) x0
# Clause #546 W:(1 0)
# Clause #547 W:(0 0)
# Clause #548 W:(3 2)
# Clause #549 W:(-1 3)
# Clause #550 W:(0 0)
# Clause #551 W:(3 1)
# Clause #552 W:(0 0) x23
# Clause #553 W:(1 -1) x22
# Clause #554 W:(5 -1)
# Clause #555 W:(3 -1)
# Clause #556 W:(1 -1)
# Clause #557 W:(0 -1)
# Clause #558 W:(0 1)
# Clause #559 W:(0 0) x7
# Clause #560 W:(-2 1)
# Clause #561 W:(-1 -1)
# Clause #562 W:(-2 -1)
# Clause #563 W:(2 0)
# Clause #564 W:(2 0) x10
# Clause #565 W:(-1 -2)
# Clause #566 W:(-1 -1)
# Clause #567 W:(0 0) x5
# Clause #568 W:(-1 2)
# Clause #569 W:(-1 0)
# Clause #570 W:(-1 2)
# Clause #571 W:(-1 1)
# Clause #572 W:(-1 0)
# Clause #573 W:(0 3)
# Clause #574 W:(0 -1)
# Clause #575 W:(0 0)
# Clause #576 W:(0 -2) x23
# Clause #577 W:(3 0)
# Clause #578 W:(0 -1)
# Clause #579 W:(2 -1)
# Clause #580 W:(-2 0)
# Clause #581 W:(0 0)
# Clause #582 W:(-1 -1)
# Clause #583 W:(2 0)
# Clause #584 W:(0 0)
# Clause #585 W:(-2 0)
# Clause #586 W:(0 -1) x3
# Clause #587 W:(-2 -2)
# Clause #588 W:(0 -1)
# Clause #589 W:(0 0)
# Clause #590 W:(2 -1)
# Clause #591 W:(0 0)
# Clause #592 W:(-1 0)
# Clause #593 W:(0 -1)
# Clause #594 W:(-1 -1)
# Clause #595 W:(4 -1)
# Clause #596 W:(3 -1)
# Clause #597 W:(1 0)
# Clause #598 W:(0 -4)
# Clause #599 W:(1 2)
# Clause #600 W:(0 0)
# Clause #601 W:(0 0)
# Clause #602 W:(-1 -1)
# Clause #603 W:(-2 0)
# Clause #604 W:(1 -1)
# Clause #605 W:(-1 0)
# Clause #606 W:(0 1)
# Clause #607 W:(-1 -1)
# Clause #608 W:(0 1)
# Clause #609 W:(0 0)
# Clause #610 W:(2 1)
# Clause #611 W:(-3 0)
# Clause #612 W:(-1 1)
# Clause #613 W:(-1 0)
# Clause #614 W:(-3 0)
# Clause #615 W:(0 0)
# Clause #616 W:(-1 -2)
# Clause #617 W:(-1 1)
# Clause #618 W:(2 0)
# Clause #619 W:(-1 1)
# Clause #620 W:(-1 0)
# Clause #621 W:(1 -1)
# Clause #622 W:(0 0)
# Clause #623 W:(0 1)
# Clause #624 W:(0 1)
# Clause #625 W:(0 -2)
# Clause #626 W:(-1 -1) x15
# Clause #627 W:(-1 0) x20 AND x24
# Clause #628 W:(0 1)
# Clause #629 W:(0 -1)
# Clause #630 W:(0 -1)
# Clause #631 W:(0 -3)
# Clause #632 W:(-2 -1)
# Clause #633 W:(0 0) x14
# Clause #634 W:(-1 0)
# Clause #635 W:(0 0)
# Clause #636 W:(-1 -1)
# Clause #637 W:(-1 -1)
# Clause #638 W:(1 0)
# Clause #639 W:(-1 -1) x18
# Clause #640 W:(-1 -1)
# Clause #641 W:(-4 -1)
# Clause #642 W:(-2 -2)
# Clause #643 W:(3 1)
# Clause #644 W:(-1 2)
# Clause #645 W:(0 -2)
# Clause #646 W:(1 -1) x10
# Clause #647 W:(-2 -2)
# Clause #648 W:(2 0) x1
# Clause #649 W:(1 1)
# Clause #650 W:(2 2)
# Clause #651 W:(1 3)
# Clause #652 W:(4 0)
# Clause #653 W:(-2 -1)
# Clause #654 W:(0 -2)
# Clause #655 W:(-4 -1)
# Clause #656 W:(2 1)
# Clause #657 W:(-1 0)
# Clause #658 W:(-1 -2)
# Clause #659 W:(1 0)
# Clause #660 W:(-1 0)
# Clause #661 W:(1 0)
# Clause #662 W:(0 1)
# Clause #663 W:(-1 -2)
# Clause #664 W:(-1 1)
# Clause #665 W:(2 -1)
# Clause #666 W:(-1 -1)
# Clause #667 W:(-1 -1)
# Clause #668 W:(-1 1)
# Clause #669 W:(3 1) x25
# Clause #670 W:(1 -1)
# Clause #671 W:(1 -1)
# Clause #672 W:(0 4)
# Clause #673 W:(0 -1) x22
# Clause #674 W:(0 0)
# Clause #675 W:(-1 0)
# Clause #676 W:(0 -1)
# Clause #677 W:(-2 0)
# Clause #678 W:(0 1)
# Clause #679 W:(1 0)
# Clause #680 W:(1 -1)
# Clause #681 W:(-1 0)
# Clause #682 W:(1 2)
# Clause #683 W:(-3 -1)
# Clause #684 W:(-3 -1)
# Clause #685 W:(-1 -3)
# Clause #686 W:(-1 0)
# Clause #687 W:(3 -1)
# Clause #688 W:(3 -1)
# Clause #689 W:(3 2)
# Clause #690 W:(-1 -1)
# Clause #691 W:(-3 -2)
# Clause #692 W:(-1 -2)
# Clause #693 W:(1 0)
# Clause #694 W:(-1 0)
# Clause #695 W:(-1 0)
# Clause #696 W:(-1 1) x0
# Clause #697 W:(0 1) x24
# Clause #698 W:(0 -1) x0
# Clause #699 W:(0 -1)
# Clause #700 W:(1 1)
# Clause #701 W:(-1 0)
# Clause #702 W:(2 0)
# Clause #703 W:(0 1)
# Clause #704 W:(-1 -1)
# Clause #705 W:(-1 -2)
# Clause #706 W:(-4 0)
# Clause #707 W:(-2 0)
# Clause #708 W:(1 0) x5
# Clause #709 W:(-1 2)
# Clause #710 W:(1 -1)
# Clause #711 W:(4 0)
# Clause #712 W:(0 -2)
# Clause #713 W:(-1 -1)
# Clause #714 W:(-1 0)
# Clause #715 W:(-4 0)
# Clause #716 W:(0 0)
# Clause #717 W:(0 0)
# Clause #718 W:(0 0)
# Clause #719 W:(0 -1)
# Clause #720 W:(-1 -2)
# Clause #721 W:(-1 -1)
# Clause #722 W:(1 -1)
# Clause #723 W:(1 0)
# Clause #724 W:(2 0)
# Clause #725 W:(0 3) x30
# Clause #726 W:(2 0)
# Clause #727 W:(0 0)
# Clause #728 W:(0 -1)
# Clause #729 W:(-1 0)
# Clause #730 W:(0 0)
# Clause #731 W:(-1 0) x0
# Clause #732 W:(2 -1)
# Clause #733 W:(1 0)
# Clause #734 W:(-1 1) x18
# Clause #735 W:(0 1)
# Clause #736 W:(-2 0)
# Clause #737 W:(-1 0)
# Clause #738 W:(1 0)
# Clause #739 W:(-2 -3)
# Clause #740 W:(0 -1)
# Clause #741 W:(-3 0)
# Clause #742 W:(-4 -3)
# Clause #743 W:(-1 1)
# Clause #744 W:(0 2)
# Clause #745 W:(1 -1)
# Clause #746 W:(-1 0)
# Clause #747 W:(2 -1) x20
# Clause #748 W:(0 0)
# Clause #749 W:(-1 -3)
# Clause #750 W:(-1 -1)
# Clause #751 W:(-1 5)
# Clause #752 W:(-1 -1)
# Clause #753 W:(4 -1) x0
# Clause #754 W:(0 -3)
# Clause #755 W:(-1 -1)
# Clause #756 W:(-2 -1)
# Clause #757 W:(-1 -2) x4
# Clause #758 W:(-1 4)
# Clause #759 W:(5 0) x18
# Clause #760 W:(-1 1)
# Clause #761 W:(-1 1)
# Clause #762 W:(-1 -1)
# Clause #763 W:(-1 0)
# Clause #764 W:(0 -1)
# Clause #765 W:(6 2)
# Clause #766 W:(0 1)
# Clause #767 W:(0 1)
# Clause #768 W:(0 -1)
# Clause #769 W:(1 1)
# Clause #770 W:(0 -1)
# Clause #771 W:(1 0)
# Clause #772 W:(-1 -1)
# Clause #773 W:(-2 -1)
# Clause #774 W:(-1 1)
# Clause #775 W:(-1 1)
# Clause #776 W:(-1 -1)
# Clause #777 W:(1 0) x20
# Clause #778 W:(0 -1) x18
# Clause #779 W:(3 2)
# Clause #780 W:(0 2)
# Clause #781 W:(2 -1)
# Clause #782 W:(1 2)
# Clause #783 W:(0 0)
# Clause #784 W:(-1 1)
# Clause #785 W:(0 -1)
# Clause #786 W:(-1 0)
# Clause #787 W:(-1 -1)
# Clause #788 W:(1 0)
# Clause #789 W:(2 -1)
# Clause #790 W:(1 1)
# Clause #791 W:(-1 -1)
# Clause #792 W:(3 1)
# Clause #793 W:(1 0) x20
# Clause #794 W:(-1 -1)
# Clause #795 W:(0 0)
# Clause #796 W:(7 0)
# Clause #797 W:(-3 -3)
# Clause #798 W:(-1 1) x26
# Clause #799 W:(2 0)
# Clause #800 W:(0 1)
# Clause #801 W:(1 0)
# Clause #802 W:(0 -1)
# Clause #803 W:(-1 0) x19
# Clause #804 W:(1 0)
# Clause #805 W:(-2 -1)
# Clause #806 W:(-1 0)
# Clause #807 W:(-1 0)
# Clause #808 W:(-3 0)
# Clause #809 W:(2 1)
# Clause #810 W:(-1 -1)
# Clause #811 W:(0 3) x12
# Clause #812 W:(0 0)
# Clause #813 W:(3 -1)
# Clause #814 W:(-1 1) x23
# Clause #815 W:(-1 0)
# Clause #816 W:(0 2)
# Clause #817 W:(-1 1)
# Clause #818 W:(-1 0)
# Clause #819 W:(-1 -1)
# Clause #820 W:(-1 2)
# Clause #821 W:(1 5)
# Clause #822 W:(0 4)
# Clause #823 W:(2 -1)
# Clause #824 W:(0 -1)
# Clause #825 W:(1 0)
# Clause #826 W:(0 0)
# Clause #827 W:(3 0)
# Clause #828 W:(-1 6)
# Clause #829 W:(0 4)
# Clause #830 W:(0 -1)
# Clause #831 W:(0 1)
# Clause #832 W:(-2 0)
# Clause #833 W:(0 0)
# Clause #834 W:(0 1)
# Clause #835 W:(3 0)
# Clause #836 W:(0 0)
# Clause #837 W:(-2 0)
# Clause #838 W:(-2 0)
# Clause #839 W:(0 -1) x27
# Clause #840 W:(0 0)
# Clause #841 W:(0 0)
# Clause #842 W:(1 -1)
# Clause #843 W:(-1 0)
# Clause #844 W:(-2 -1)
# Clause #845 W:(-1 0)
# Clause #846 W:(0 1)
# Clause #847 W:(1 0)
# Clause #848 W:(1 0)
# Clause #849 W:(-1 1)
# Clause #850 W:(-1 -1)
# Clause #851 W:(5 1)
# Clause #852 W:(1 -1)
# Clause #853 W:(0 3)
# Clause #854 W:(0 0)
# Clause #855 W:(0 1)
# Clause #856 W:(-3 -2) x7
# Clause #857 W:(1 -1)
# Clause #858 W:(1 0)
# Clause #859 W:(0 -1)
# Clause #860 W:(3 5) x7
# Clause #861 W:(-1 0)
# Clause #862 W:(1 0)
# Clause #863 W:(-1 -4)
# Clause #864 W:(-2 -2)
# Clause #865 W:(0 0)
# Clause #866 W:(0 0)
# Clause #867 W:(-1 -1)
# Clause #868 W:(2 0) x4
# Clause #869 W:(-1 0)
# Clause #870 W:(-1 0)
# Clause #871 W:(0 0)
# Clause #872 W:(-1 1)
# Clause #873 W:(1 3) x17 AND x26
# Clause #874 W:(0 0)
# Clause #875 W:(0 0)
# Clause #876 W:(5 -1)
# Clause #877 W:(-2 -2)
# Clause #878 W:(0 0)
# Clause #879 W:(1 -1)
# Clause #880 W:(0 -1)
# Clause #881 W:(0 1)
# Clause #882 W:(-1 0)
# Clause #883 W:(1 0)
# Clause #884 W:(0 1)
# Clause #885 W:(-1 0)
# Clause #886 W:(-2 -1)
# Clause #887 W:(-1 3)
# Clause #888 W:(1 -1)
# Clause #889 W:(0 1)
# Clause #890 W:(2 1)
# Clause #891 W:(-1 0)
# Clause #892 W:(1 0) x8
# Clause #893 W:(2 0)
# Clause #894 W:(-3 0)
# Clause #895 W:(0 3)
# Clause #896 W:(-1 -1) x28
# Clause #897 W:(-1 1)
# Clause #898 W:(0 0) x10
# Clause #899 W:(-1 -1)
# Clause #900 W:(-1 0)
# Clause #901 W:(-1 -1)
# Clause #902 W:(1 3)
# Clause #903 W:(0 1)
# Clause #904 W:(0 2)
# Clause #905 W:(-1 0)
# Clause #906 W:(-2 -1)
# Clause #907 W:(-1 -1)
# Clause #908 W:(2 0)
# Clause #909 W:(0 2)
# Clause #910 W:(2 -1)
# Clause #911 W:(-1 0)
# Clause #912 W:(-1 -1)
# Clause #913 W:(-1 1)
# Clause #914 W:(1 -1) x4
# Clause #915 W:(-2 0)
# Clause #916 W:(0 -1)
# Clause #917 W:(-1 -2)
# Clause #918 W:(-1 -2)
# Clause #919 W:(-1 0)
# Clause #920 W:(0 6) x6
# Clause #921 W:(0 0)
# Clause #922 W:(-3 0) x20
# Clause #923 W:(0 0)
# Clause #924 W:(0 0) x11
# Clause #925 W:(2 0)
# Clause #926 W:(2 0) x11
# Clause #927 W:(-2 -1) x8
# Clause #928 W:(-2 -1)
# Clause #929 W:(1 0)
# Clause #930 W:(-1 -4)
# Clause #931 W:(-3 -2)
# Clause #932 W:(-2 0)
# Clause #933 W:(-1 0) x5
# Clause #934 W:(0 0)
# Clause #935 W:(2 -1)
# Clause #936 W:(0 -1)
# Clause #937 W:(0 0)
# Clause #938 W:(1 2)
# Clause #939 W:(0 0) x1
# Clause #940 W:(-1 0) x1
# Clause #941 W:(-1 0)
# Clause #942 W:(2 0) x27
# Clause #943 W:(0 1)
# Clause #944 W:(0 -1)
# Clause #945 W:(1 2)
# Clause #946 W:(0 -1)
# Clause #947 W:(2 0)
# Clause #948 W:(1 -1)
# Clause #949 W:(-2 -1)
# Clause #950 W:(0 0) x4
# Clause #951 W:(0 0)
# Clause #952 W:(-1 0)
# Clause #953 W:(1 -1)
# Clause #954 W:(-3 0)
# Clause #955 W:(0 0)
# Clause #956 W:(0 -1)
# Clause #957 W:(-3 -3)
# Clause #958 W:(0 0)
# Clause #959 W:(1 0)
# Clause #960 W:(-1 0)
# Clause #961 W:(-1 -1)
# Clause #962 W:(1 1)
# Clause #963 W:(-1 -1)
# Clause #964 W:(0 -1)
# Clause #965 W:(1 -1)
# Clause #966 W:(2 -1)
# Clause #967 W:(-1 3)
# Clause #968 W:(-1 -1)
# Clause #969 W:(-1 1)
# Clause #970 W:(0 1)
# Clause #971 W:(1 0)
# Clause #972 W:(0 4)
# Clause #973 W:(-1 -1)
# Clause #974 W:(0 0)
# Clause #975 W:(-2 -1) x25
# Clause #976 W:(0 0)
# Clause #977 W:(-1 11)
# Clause #978 W:(0 -1)
# Clause #979 W:(3 -1)
# Clause #980 W:(-1 2)
# Clause #981 W:(0 -4)
# Clause #982 W:(0 0)
# Clause #983 W:(2 4)
# Clause #984 W:(0 -3)
# Clause #985 W:(-1 -2)
# Clause #986 W:(1 5)
# Clause #987 W:(-2 0)
# Clause #988 W:(0 1)
# Clause #989 W:(5 1)
# Clause #990 W:(1 1)
# Clause #991 W:(-1 0)
# Clause #992 W:(1 0) x5
# Clause #993 W:(-1 -1)
# Clause #994 W:(0 -1)
# Clause #995 W:(-3 -1)
# Clause #996 W:(-2 0)
# Clause #997 W:(1 3)
# Clause #998 W:(0 0)
# Clause #999 W:(-1 1) x2
# [[ 6  3]
#  [ 7 16]
#  [20  6]]
# [[195 245]
#  [ 87 217]
#  [165 130]
#  ...
#  [120 125]
#  [118 245]
#  [125 114]]
# {'Plain': 0}

# %%
def run_a_point(C, T, s):
    tm = MultiClassGraphTsetlinMachine(
    C,
    T,
    s,
    depth = args.depth,
    message_size = args.message_size,
    message_bits = args.message_bits,
    max_included_literals = args.max_included_literals
    )
    
    for i in range(args.epochs):
        start_training = time()
        tm.fit(graphs_train, Y_train, epochs=1, incremental=True)
        stop_training = time()
    
        start_testing = time()
        #print(tm.predict(graphs_test))
        result_test = 100*(tm.predict(graphs_test) == Y_test).mean()
        stop_testing = time()
    
        result_train = 100*(tm.predict(graphs_train) == Y_train).mean()
    
        #print("%d %.2f %.2f %.2f %.2f" % (i, result_train, result_test, stop_training-start_training, stop_testing-start_testing))
    return result_test, result_train

# %%
C_list = []
T_list = []
s_list = []
test_r = []
train_r = []
for i in range(100):
    print("started training for", i+1)
    C = random.randint(100, 10000)
    T = random.randint(100, 5000)
    s = random.randint(1, 50)
    result_test_, result_train_ = run_a_point(C, T, s)
    print(result_test_, result_train_)
    test_r.append(result_test_)
    train_r.append(result_train_)
    C_list.append(C)
    T_list.append(T)
    s_list.append(s)
